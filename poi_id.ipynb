# %%
#!/usr/bin/python

import sys
import pickle
import pandas as pd
import numpy as np
from functools import partial

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
# from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer#, \
    # IterativeImputer # requires sklearn.experimental.enable_iterative_imputer

# from sklearn.feature_selection import SelectPercentile, SelectFromModel, f_classif, mutual_info_classif, chi2,\
#                                         SelectFpr, SelectFdr, RFECV
from sklearn.feature_selection import SelectPercentile, f_classif, mutual_info_classif, chi2
# from sklearn.decomposition import FastICA, IncrementalPCA, KernelPCA, PCA, TruncatedSVD

from sklearn.cluster import KMeans
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn import svm

from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support

### My imports
sys.path.append('tools/')
from dos2unix import crlf_to_lf # Borrowed and modified from multiple sources.
from train_test import run_skl, get_base_perfs, search_em_all
from feature_engineering import set_all_ratios, quant_flag_all, out_flag_all, flag_signs, add_k_means_n

### Udacity imports (deprecated)
# from feature_format import featureFormat, targetFeatureSplit
# from tester import dump_classifier_and_data

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
##########################################################################################
### Udacity comments are in [].
### [Load the dictionary containing the dataset]
### Make the dict a dataframe because they're easier to work with.
data_df = None #pd.DataFrame()
fp = crlf_to_lf(f_in_path='data/final_project_dataset.pkl')
with open(fp, 'rb') as data_file:
    data_df = pd.DataFrame(pickle.load(data_file)).T

##########################################################################################
### [Task 1: Select what features you'll use.]
### Task 1: Clean up and select what features and subsets *not* to use.
### (Further feature selection will happen after feature engineering.)
print('Cleaning data.')
### Drop email_address because it's a signature.
data_df.drop(columns='email_address', inplace=True)
### Drop the TOTAL row.
data_df.drop(labels=['TOTAL', 'THE TRAVEL AGENCY IN THE PARK'], inplace=True)

### Handle missing values here.
### Replacing 'NaN' with None had a weird result in which values from some
### rows were copied into the missing values of neighboring rows. No idea why.
### Using np.nan did not have that result as far as I can tell.
### But it is a float missing value and thus casts the column as float,
### or as object when other values are not floats.
data_df.replace(to_replace='NaN', value=np.nan, inplace=True)

### [features_list is a list of strings, each of which is a feature name.
### The first feature must be "poi".]
###    (if using featureFormat(), which I don't).

### All units are in USD.
fin_features = ['salary', 'bonus', 'long_term_incentive', 'deferred_income', 'deferral_payments',
                'loan_advances', 'other', 'expenses', 'director_fees', 'total_payments',
                'exercised_stock_options', 'restricted_stock', 'restricted_stock_deferred', 'total_stock_value']
pay_features = fin_features[:10]
stock_features = fin_features[10:]
    
### Units are number of emails messages;
email_features = ['to_messages', 'from_poi_to_this_person', 'from_messages', 'from_this_person_to_poi',
                  'shared_receipt_with_poi']

### Boolean, represented as integer.
POI_label = ['poi']

### The first feature must be "poi" if using featureFormat().
features_list = POI_label + fin_features + email_features

### Imputation recasts as float, but as object if left as bool, so set it to int for now.
data_df['poi'] = data_df['poi'].astype(dtype=int)

### Belfer's financial data is shifted one column to the right.
### Shift it one to the left, financial data only.
### Make total_stock_value np.nan for consistency until imputation, but could be 0.
### May remove this row for so many NaNs, but fix it now anyway.
data_df.loc[data_df.index == 'BELFER ROBERT', fin_features] \
    = data_df.loc[data_df.index == 'BELFER ROBERT', fin_features].shift(periods=-1, axis='columns',
                                                                        fill_value=np.nan)

### Bhatnagar's financial data is shifted one to the left.
### Shift it one to the right, financial data only.
### Make salary np.nan.
data_df.loc[data_df.index == 'BHATNAGAR SANJAY', fin_features] \
    = data_df.loc[data_df.index == 'BHATNAGAR SANJAY', fin_features].shift(periods=1, axis='columns',
                                                                           fill_value=np.nan)

### Set totals to sum of values where any values are not NaN.
### i.e. don't make 0 totals NaN, even though some NaN values may be included.
### Makes these rows consistent with other rows that include NaNs and numbers yet have a nonNaN total.
data_df.loc[~(data_df[pay_features].isna().all(axis='columns')), 'total_payments'] \
    = data_df[pay_features[:-1]].sum(axis='columns')
data_df.loc[~(data_df[stock_features].isna().all(axis='columns')), 'total_stock_value'] \
    = data_df[stock_features[:-1]].sum(axis='columns')

### Add one to Glisan's to_message to at least equal shared_receipt_with_poi.
data_df.loc['GLISAN JR BEN F', 'to_messages'] = 874

### Drop features that are too sparse.
drop_feats_lst = ['loan_advances']
data_df.drop(columns=drop_feats_lst, inplace=True)
fin_features = [feat for feat in fin_features if feat not in drop_feats_lst]
pay_features = [feat for feat in pay_features if feat not in drop_feats_lst]
stock_features = [feat for feat in stock_features if feat not in drop_feats_lst]
email_features = [feat for feat in email_features if feat not in drop_feats_lst]
features_list = [feat for feat in features_list if feat not in drop_feats_lst]

### Removed 'email' as signature upon loading.

### Drop persons who have NaN payment totals or NaN stock totals or NaN to_messages or NaN from_messages,
### and are missing 70% of their values.
### (Already made sure that all totals are not NaN if they have subvalues.)
nan_limit = 0.7 * len(data_df.columns)
sparse_records_idx_arr = \
    data_df.loc[data_df['total_payments'].isna() \
                | data_df['total_stock_value'].isna() \
                | data_df['to_messages'].isna() \
                | data_df['from_messages'].isna()]\
           .loc[data_df.isna().sum(axis='columns') > nan_limit]\
           .index.values
data_df.drop(labels=sparse_records_idx_arr, inplace=True)

### This leaves 123 records over 19 features.


### Make a quick baseline model for comparison.

### Alphabetize index before split for Udacity compatibility because that's what they'll do.
### I knew this, but missed it until the end. I'd decided from the start not to use their deprecated
### scripts based on dictionaries, specifically feature_format, and wrote my own using pandas. 
### The rest of my cleaning and engineering are based on a different split.
### My mistake. Rookie lesson learned: pay closer attention to what the legacy code does, especially 
### expected input/output structures.
data_df.sort_index(inplace=True)

### Split now for baseline model, but also before further processing, outlier removal, scaling, engineering,
### or else test set info leaks into training set.
### Even imputation could if using multivariate imputation or median.
### Decisions on how to treat the data should not be influenced by test set either.
X_train, X_test, y_train, y_test \
    = train_test_split(data_df[features_list[1:]], data_df[['poi']], test_size=.3, random_state=42)
### Some algorithms want 1D y data.
y_train_1d = np.ravel(y_train.astype(bool))
y_test_1d = np.ravel(y_test.astype(bool))

### Split train set again for a baseline model that won't touch the final test set.
X_train_base, X_test_base, y_train_base, y_test_base \
    = train_test_split(X_train, y_train, test_size=.3, random_state=42)
y_train_1d_base = np.ravel(y_train_base.astype(bool))
y_test_1d_base = np.ravel(y_test_base.astype(bool))

### Impute with 0.
imp_0 = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value=0, copy=False)
imp_0 = imp_0.fit(X=X_train_base)
X_train_base_imp0 = pd.DataFrame(data=imp_0.transform(X=X_train_base), columns=X_train_base.columns,
                                 index=X_train_base.index)
X_test_base_imp0 = pd.DataFrame(data=imp_0.transform(X=X_test_base), columns=X_test_base.columns,
                                index=X_test_base.index)

### For metrics dataframe if you want to save and inspect them.
ordered_cols_lst = ['nonPOI_prec', 'POI_prec', 'nonPOI_rec', 'POI_rec', 'nonPOI_f', 'POI_f', 'nonPOI_sup',
                    'POI_sup', 't_neg', 'f_neg', 'f_pos', 't_pos', 'train_t', 'predict_t', 'model']
base_perf_df = pd.DataFrame(columns=ordered_cols_lst)

clf_dict = {'dt_clf': DecisionTreeClassifier, 'rf_clf': RandomForestClassifier, 'ab_clf': AdaBoostClassifier,
            'kn_clf': KNeighborsClassifier, 'gnb_clf': GaussianNB, 'svc_clf': svm.SVC}

print('\nBaseline model performance metrics, no engineered features or tuning, imputed NaNs with 0, using a train-test split of the training set:\n')
for key, method in clf_dict.items():
    _, _, _, _, perf_sr = run_skl(method=method, X_train=X_train_base_imp0,
                                  y_train=y_train_1d_base,
                                  X_test=X_test_base_imp0,
                                  y_test=y_test_1d_base,
                                  perf_series=key)
    base_perf_df = base_perf_df.append(perf_sr)
    
### Save a full copy of basic split sets for baseline comparison once final model is built.
X_train_base = X_train.copy()
X_train_base = pd.DataFrame(data=imp_0.transform(X=X_train_base), columns=X_train_base.columns,
                            index=X_train_base.index)
X_test_base = X_train.copy()
X_test_base = pd.DataFrame(data=imp_0.transform(X=X_test_base), columns=X_test_base.columns,
                           index=X_test_base.index)
y_train_base = np.ravel(y_train.astype(bool))
y_test_base = np.ravel(y_test.astype(bool))
# Out:
# data/final_project_dataset.pkl saved as data/final_project_dataset_unix.pkl in 6705 bytes.
# Cleaning data.
#
# Baseline model performance metrics, no engineered features or tuning, imputed NaNs with 0, using a train-test split of the training set:
#
# DecisionTreeClassifier()
# Training time: 0.002 s
# Prediction time: 0.001 s
# Confusion matrix:
#  [[18  4]
#  [ 3  1]]
# Precision, recall, f beta score, support:
#  (array([0.85714286, 0.2       ]), array([0.81818182, 0.25      ]), array([0.8372093 , 0.22222222]), array([22,  4], dtype=int64))
#
# RandomForestClassifier()
# Training time: 0.104 s
# Prediction time: 0.005 s
# Confusion matrix:
#  [[22  0]
#  [ 4  0]]
# Precision, recall, f beta score, support:
#  (array([0.84615385, 0.        ]), array([1., 0.]), array([0.91666667, 0.        ]), array([22,  4], dtype=int64))
#
# AdaBoostClassifier()
# Training time: 0.052 s
# Prediction time: 0.006 s
# Confusion matrix:
#  [[20  2]
#  [ 3  1]]
# Precision, recall, f beta score, support:
#  (array([0.86956522, 0.33333333]), array([0.90909091, 0.25      ]), array([0.88888889, 0.28571429]), array([22,  4], dtype=int64))
#
# KNeighborsClassifier()
# Training time: 0.002 s
# Prediction time: 0.002 s
# Confusion matrix:
#  [[22  0]
#  [ 4  0]]
# Precision, recall, f beta score, support:
#  (array([0.84615385, 0.        ]), array([1., 0.]), array([0.91666667, 0.        ]), array([22,  4], dtype=int64))
#
# GaussianNB()
# Training time: 0.001 s
# Prediction time: 0.001 s
# Confusion matrix:
#  [[16  6]
#  [ 1  3]]
# Precision, recall, f beta score, support:
#  (array([0.94117647, 0.33333333]), array([0.72727273, 0.75      ]), array([0.82051282, 0.46153846]), array([22,  4], dtype=int64))
#
# SVC()
# Training time: 0.002 s
# Prediction time: 0.001 s
# Confusion matrix:
#  [[22  0]
#  [ 4  0]]
# Precision, recall, f beta score, support:
#  (array([0.84615385, 0.        ]), array([1., 0.]), array([0.91666667, 0.        ]), array([22,  4], dtype=int64))
# C:\Users\kaleb\anaconda3\envs\py3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kaleb\anaconda3\envs\py3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kaleb\anaconda3\envs\py3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
##########################################################################################
### Task 2: Remove/handle outliers
print('Handling outliers.')
### Dropped ['TOTAL', 'THE TRAVEL AGENCY IN THE PARK'] row upon loading.

### Drop features that are too sparse.
### Drop 'other' because it's ill-defined and seems overly represented within important features.
### The nebulous nature of it seems like a good fit for fraud, but high gross 'other' amounts are more associated
### with nonPOIs than POIs if anything.
drop_feats_lst = ['director_fees', 'restricted_stock_deferred', 'other']

X_train.drop(columns=drop_feats_lst, inplace=True)
X_test.drop(columns=drop_feats_lst, inplace=True)
data_df.drop(columns=drop_feats_lst, inplace=True)

fin_features = [feat for feat in fin_features if feat not in drop_feats_lst]
pay_features = [feat for feat in pay_features if feat not in drop_feats_lst]
stock_features = [feat for feat in stock_features if feat not in drop_feats_lst]
email_features = [feat for feat in email_features if feat not in drop_feats_lst]
features_list = [feat for feat in features_list if feat not in drop_feats_lst]
del drop_feats_lst

### Don't drop records now because it will mess up the split for Udacity.
### Could drop earlier and resplit, but I've already done a lot of EDA behind the scenes.
### NaN his financials instead.
X_train.loc[['POWERS WILLIAM'], pay_features] = np.nan
data_df.loc[['POWERS WILLIAM'], pay_features] = np.nan

### Bivariate linear regression of the ratios between to/from/shared with POIs and
### total to and from messages revealed that top coding to_messages and from_messages
### may slightly aid nonPOI precision.
### Only top coding the training set in order to bias the model,
### because I am less concerned with accuracy than I am with POI recall,
### and by extension, nonPOI precision.
X_train['to_messages'] = X_train['to_messages'].apply(lambda x: x if x < 12000 or np.isnan(x) else 12000)
X_train['from_messages'] = X_train['from_messages'].apply(lambda x: x if x < 8000 or np.isnan(x) else 8000)
data_df.loc[X_train.index]['to_messages'] \
    = data_df.loc[X_train.index]['to_messages'].apply(lambda x: x if x < 12000 or np.isnan(x) else 12000)
data_df.loc[X_train.index]['from_messages'] \
    = data_df.loc[X_train.index]['from_messages'].apply(lambda x: x if x < 8000 or np.isnan(x) else 8000)

### Not sure whether top coding these will really help or hinder, if anything at all.
### But, it appears to potentially aid POI recall in some cases
### when comparing payments to totals, and it's more in line with best practices.
### Only really affects Frevert.
top = X_train['total_payments'].dropna().sort_values()[-2]
X_train['total_payments'] = X_train['total_payments'].apply(lambda x : x if x < top or np.isnan(x) else top)
data_df.loc[X_train.index]['total_payments'] \
    = data_df.loc[X_train.index]['total_payments'].apply(lambda x : x if x < top or np.isnan(x) else top)

top = X_train['long_term_incentive'].dropna().sort_values()[-2]
X_train['long_term_incentive'] = \
    X_train['long_term_incentive'].apply(lambda x : x if x < top or np.isnan(x) else top)
data_df.loc[X_train.index]['long_term_incentive'] \
    = data_df.loc[X_train.index]['long_term_incentive'].apply(lambda x : x if x < top or np.isnan(x) else top)

### Same story as Powers, NaN all of Belfer instead of simply dropping.
X_train.loc['BELFER ROBERT'] = np.nan
# belfers_poi = data_df.loc['BELFER ROBERT']['poi']
data_df.loc['BELFER ROBERT', features_list[1:]]= np.nan
# data_df.loc['BELFER ROBERT']['poi'] = belfers_poi

### After look at distributions of ratios of features, more top/bottom coding. ###

### Nan Bannantine's salary, and bottom code salary.
X_train.loc['BANNANTINE JAMES M', 'salary'] = np.nan
data_df.loc['BANNANTINE JAMES M', 'salary'] = np.nan
bottom = X_train['salary'].dropna().sort_values(ascending=False)[-2]
X_train['salary'] = X_train['salary'].apply(lambda x : x if x > bottom or np.isnan(x) else bottom)
data_df.loc[X_train.index]['salary'] \
    = data_df.loc[X_train.index]['salary'].apply(lambda x : x if x > bottom or np.isnan(x) else bottom)

### These two only have one, very low payment value.
# X_train.loc[['HAYES ROBERT E', 'HAUG DAVID L'], pay_features] = np.nan
# data_df.loc[['HAYES ROBERT E', 'HAUG DAVID L'], pay_features] = np.nan
X_train.loc[['HAYES ROBERT E'], pay_features] = np.nan
data_df.loc[['HAYES ROBERT E'], pay_features] = np.nan

### Top code deferred_income.
top = X_train['deferred_income'].dropna().sort_values(ascending=True)[-3]
X_train['deferred_income'] = X_train['deferred_income'].apply(lambda x : x if x < top or np.isnan(x) else top)
data_df.loc[X_train.index]['deferred_income'] = \
    data_df.loc[X_train.index]['deferred_income'].apply(lambda x : x if x < top or np.isnan(x) else top)
del top
del bottom
# Out:
# Handling outliers.

# %%
##########################################################################################
### Task 3: Create new feature(s)
print('Engineering features.')
### Start with all ratios, within respective subspaces (fin:fin, e:e).

### Add financial ratios within subspaces to data sets.
pay_feats_divby_df = set_all_ratios(df=X_train, denoms=pay_features, numers=pay_features)
stock_feats_divby_df = set_all_ratios(df=X_train, denoms=stock_features, numers=stock_features)
### Only plausible email ratios (all reciprocals still, to get the 0s to infs):
to_lst = ['to_messages', 'from_poi_to_this_person', 'shared_receipt_with_poi']
from_lst = ['from_messages', 'from_this_person_to_poi']
email_to_divby_df = set_all_ratios(df=X_train, denoms=to_lst, numers=to_lst)
email_from_divby_df = set_all_ratios(df=X_train, denoms=from_lst, numers=from_lst)

X_train = pd.concat(objs=[X_train, pay_feats_divby_df, stock_feats_divby_df, email_to_divby_df,
                          email_from_divby_df], axis=1)

### Do for test set.
pay_feats_divby_df = set_all_ratios(df=X_test, denoms=pay_features, numers=pay_features)
stock_feats_divby_df = set_all_ratios(df=X_test, denoms=stock_features, numers=stock_features)
email_to_divby_df = set_all_ratios(df=X_test, denoms=to_lst, numers=to_lst)
email_from_divby_df = set_all_ratios(df=X_test, denoms=from_lst, numers=from_lst)
X_test = pd.concat(objs=[X_test, pay_feats_divby_df, stock_feats_divby_df, email_to_divby_df,
                         email_from_divby_df], axis=1)

### Do for full set.
pay_feats_divby_df = set_all_ratios(df=data_df, denoms=pay_features, numers=pay_features)
stock_feats_divby_df = set_all_ratios(df=data_df, denoms=stock_features, numers=stock_features)
email_to_divby_df = set_all_ratios(df=data_df, denoms=to_lst, numers=to_lst)
email_from_divby_df = set_all_ratios(df=data_df, denoms=from_lst, numers=from_lst)
data_df = pd.concat(objs=[data_df, pay_feats_divby_df, stock_feats_divby_df, email_to_divby_df,
                          email_from_divby_df], axis=1)
del to_lst
del from_lst

### Set all np.inf to np.nan.
set_inf = lambda col: col.apply(func=(lambda x: np.nan if abs(x) == abs(np.inf) else x))
X_train = X_train.apply(func=set_inf)
X_test = X_test.apply(func=set_inf)
data_df = data_df.apply(func=set_inf)

### Remove all features containing less than 30% training observations.
drop_lst = list(X_train.count().loc[X_train.count() < .3 * len(X_train.index)].index)
X_train.drop(columns=drop_lst, inplace=True)
X_test.drop(columns=drop_lst, inplace=True)
data_df.drop(columns=drop_lst, inplace=True)

pay_feats_divby_lst = [feat for feat in list(pay_feats_divby_df.columns) if not feat in drop_lst]
stock_feats_divby_lst = [feat for feat in list(stock_feats_divby_df.columns) if not feat in drop_lst]
email_feats_divby_lst = [feat for feat in list(email_to_divby_df.columns) if not feat in drop_lst] \
                        + [feat for feat in list(email_from_divby_df.columns) if not feat in drop_lst]
fin_features = [feat for feat in fin_features if feat not in drop_lst] + pay_feats_divby_lst \
    + stock_feats_divby_lst
pay_features = [feat for feat in pay_features if feat not in drop_lst]
stock_features = [feat for feat in stock_features if feat not in drop_lst]
email_features = [feat for feat in email_features if feat not in drop_lst] + email_feats_divby_lst
features_list = [feat for feat in features_list if feat not in drop_lst] + pay_feats_divby_lst \
    + stock_feats_divby_lst + email_feats_divby_lst
del drop_lst
# Out:
# Engineering features.

# %%
# ### Create features that flag mambership in various quantiles, outliership, and x > 0.
# ### Use multiple quantiles: quartiles, quintiles, and deciles.
# ### Retain np.nans.

# to_flag_lst = fin_features + email_features

# ### Could write a function, but I'll just paste and edit.
# ### Flag train set.
# fin_quant_flags_df = quant_flag_all(df=X_train[fin_features], quant_df=X_train[fin_features])
# email_quant_flags_df = quant_flag_all(df=X_train[email_features], quant_df=X_train[email_features])
# fin_out_flags_df = out_flag_all(df=X_train[fin_features], quant_df=X_train[fin_features])
# email_out_flags_df = out_flag_all(df=X_train[email_features], quant_df=X_train[email_features])
# sign_flags_df = flag_signs(df=X_train[to_flag_lst])
# X_train = pd.concat(objs=[X_train, fin_quant_flags_df, email_quant_flags_df, fin_out_flags_df,
#                           email_out_flags_df, sign_flags_df], axis=1)

# ### Flag test set.
# fin_quant_flags_df = quant_flag_all(df=X_test[fin_features], quant_df=X_train[fin_features])
# email_quant_flags_df = quant_flag_all(df=X_test[email_features], quant_df=X_train[email_features])
# fin_out_flags_df = out_flag_all(df=X_test[fin_features], quant_df=X_train[fin_features])
# email_out_flags_df = out_flag_all(df=X_test[email_features], quant_df=X_train[email_features])
# sign_flags_df = flag_signs(df=X_test[to_flag_lst])
# X_test = pd.concat(objs=[X_test, fin_quant_flags_df, email_quant_flags_df, fin_out_flags_df,
#                           email_out_flags_df, sign_flags_df], axis=1)

# ### Flag whole set.
# fin_quant_flags_df = quant_flag_all(df=data_df[fin_features], quant_df=X_train[fin_features])
# email_quant_flags_df = quant_flag_all(df=data_df[email_features], quant_df=X_train[email_features])
# fin_out_flags_df = out_flag_all(df=data_df[fin_features], quant_df=X_train[fin_features])
# email_out_flags_df = out_flag_all(df=data_df[email_features], quant_df=X_train[email_features])
# sign_flags_df = flag_signs(df=data_df[to_flag_lst])
# data_df = pd.concat(objs=[data_df, fin_quant_flags_df, email_quant_flags_df, fin_out_flags_df,
#                           email_out_flags_df, sign_flags_df], axis=1)

# ### Create and update feature lists.
# fin_quant_flags_lst = list(fin_quant_flags_df.columns)
# email_quant_flags_lst = list(email_quant_flags_df.columns)
# quant_flags_lst = fin_quant_flags_lst + email_quant_flags_lst

# fin_out_flags_lst = list(fin_out_flags_df.columns)
# email_out_flags_lst = list(email_out_flags_df.columns)
# out_flags_lst = fin_out_flags_lst + email_out_flags_lst

# fin_features += fin_quant_flags_lst + fin_out_flags_lst
# email_features += email_quant_flags_lst + email_out_flags_lst

# sign_flags_lst = list(sign_flags_df.columns)

# features_list = features_list + quant_flags_lst + out_flags_lst + sign_flags_lst

# del to_flag_lst
# del fin_quant_flags_df
# del email_quant_flags_df
# del fin_out_flags_df
# del email_out_flags_df
# del sign_flags_df


### Scale features.
### Would be ideal to scale in the pipeline, but I initially experimented with iterative imputation
### and feeding bools into sklearn. Not worth rewriting for this project.

### Just do min-max on floats, not bools (some are objects for now because np.nan)

float_feats_lst = fin_features + email_features
# bool_feats_lst =  sign_flags_lst

scaler = MinMaxScaler()
train_floats = pd.DataFrame(data=scaler.fit_transform(X=X_train[float_feats_lst]),
                            columns=float_feats_lst, index=X_train.index)
X_train_scaled = pd.concat(objs=[train_floats], axis=1)#, X_train[bool_feats_lst]], axis=1)

test_floats = pd.DataFrame(data=scaler.transform(X=X_test[float_feats_lst]),
                           columns=float_feats_lst,index=X_test.index)
X_test_scaled = pd.concat(objs=[test_floats], axis=1)#, X_test[bool_feats_lst]], axis=1)

all_floats = pd.DataFrame(data=scaler.transform(X=data_df[float_feats_lst]),
                          columns=float_feats_lst, index=data_df.index)
data_df_scaled = pd.concat(objs=[data_df['poi'], all_floats], axis=1)#, data_df[bool_feats_lst]], axis=1)

del float_feats_lst
del scaler
del train_floats
del test_floats
del all_floats
del X_train
del X_test
del data_df

# %%
### Impute missing values:
### Financial features to 0, email features to median, and bools to mode.
### Restore bools to bool (from object because np.nan)

imp0 = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value=0)
imp_med = SimpleImputer(missing_values=np.nan, strategy='median')
imp_mod = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

### Financial features to 0.
fin_train_df = pd.DataFrame(data=imp0.fit_transform(X=X_train_scaled[fin_features]),
                        columns=fin_features, index=X_train_scaled.index)
fin_test_df = pd.DataFrame(data=imp0.transform(X=X_test_scaled[fin_features]),
                       columns=fin_features, index=X_test_scaled.index)
fin_all_df = pd.DataFrame(data=imp0.transform(X=data_df_scaled[fin_features]),
                      columns=fin_features, index=data_df_scaled.index)

### email features to median.
email_train_df = pd.DataFrame(data=imp_med.fit_transform(X=X_train_scaled[email_features]),
                        columns=email_features, index=X_train_scaled.index)
email_test_df = pd.DataFrame(data=imp_med.transform(X=X_test_scaled[email_features]),
                       columns=email_features, index=X_test_scaled.index)
email_all_df = pd.DataFrame(data=imp_med.transform(X=data_df_scaled[email_features]),
                      columns=email_features, index=data_df_scaled.index)

# ### Bools to mode.
# ### Restore bools to bool (from object because np.nan)
# bool_train_df = (pd.DataFrame(data=imp_mod.fit_transform(X=X_train_scaled[bool_feats_lst]),
#                               columns=bool_feats_lst, index=X_train_scaled.index)).astype(bool)
# bool_test_df = pd.DataFrame(data=imp_mod.transform(X=X_test_scaled[bool_feats_lst]),
#                             columns=bool_feats_lst, index=X_test_scaled.index).astype(bool)
# bool_all_df = pd.DataFrame(data=imp_mod.transform(X=data_df_scaled[bool_feats_lst]),
#                            columns=bool_feats_lst, index=data_df_scaled.index).astype(bool)

### Concat
X_train_scaled_imp = pd.concat(objs=[fin_train_df, email_train_df], axis=1)#, bool_train_df], axis=1)
X_test_scaled_imp = pd.concat(objs=[fin_test_df, email_test_df], axis=1)#, bool_test_df], axis=1)
data_df_scaled_imp = pd.concat(objs=[data_df_scaled['poi'], fin_all_df, email_all_df], axis=1)#, bool_all_df], axis=1)

del fin_train_df
del email_train_df
# del bool_train_df
del fin_test_df
del email_test_df
# del bool_test_df
del fin_all_df
del email_all_df
# del bool_all_df
# del bool_feats_lst
del X_train_scaled
del X_test_scaled
del data_df_scaled

# %%
# ### sklearn predictions as features

# # 1) Kmeans cluster.
# train_cluster_subspace, test_cluster_subspace \
#     = add_k_means_n(X_train=X_train_scaled_imp, X_test=X_test_scaled_imp)
# X_train_scaled_imp_k = pd.concat(objs=[X_train_scaled_imp, train_cluster_subspace], axis=1)
# X_test_scaled_imp_k = pd.concat(objs=[X_test_scaled_imp, test_cluster_subspace], axis=1)

# train_cluster_subspace, test_cluster_subspace \
#     = add_k_means_n(X_train=X_train_scaled_imp, X_test=data_df_scaled_imp[features_list[1:]])
# data_df_scaled_imp_k = pd.concat(objs=[data_df_scaled_imp, test_cluster_subspace], axis=1)

# k_means_feats_lst = k_means_feats_lst = list(train_cluster_subspace.columns)
# features_list += k_means_feats_lst

# del train_cluster_subspace
# del test_cluster_subspace
# del X_train_scaled_imp
# del X_test_scaled_imp
# del data_df_scaled_imp

# %%
################################################################################################
### [Task 4: Try a varity of classifiers
### Please name your classifier clf for easy export below.
### Note that if you want to do PCA or other multi-stage operations,
### you'll need to use Pipelines. For more info:
### http://scikit-learn.org/stable/modules/pipeline.html]

# # [Provided to give you a starting point. Try a variety of classifiers.]
# from sklearn.naive_bayes import GaussianNB
# clf = GaussianNB()

### Construct baseline performance with all features before tuning/selection.
print('\nBaseline models using all engineered features, mixed imputation, train-test split of train set:\n')
### Split train set again for a baseline model that won't touch the final test set.
X_train_base, X_test_base, y_train_base, y_test_base \
    = train_test_split(X_train_scaled_imp, y_train, test_size=.3, random_state=42)
#     = train_test_split(X_train_scaled_imp_k, y_train, test_size=.3, random_state=42)
y_train_1d_base = np.ravel(y_train_base.astype(bool))
y_test_1d_base = np.ravel(y_test_base.astype(bool))

### Save metrics as a dataframe if you want to save the object and inspect it later.
base_perf_engineered_df = pd.DataFrame(columns=ordered_cols_lst)

base_perfs_dict = {'base_perf_engineered': base_perf_engineered_df}
imp_sets_dict = {'base_perf_engineered': [X_train_base, X_test_base]}

### Modifies the base_perfs_dict in place, because dict has no deep copy method.
get_base_perfs(base_perfs_dict=base_perfs_dict, imp_sets_dict=imp_sets_dict, clf_dict=clf_dict, y_train=y_train_1d_base,
               y_test=y_test_1d_base)

base_perfs_dict['first_base'] = base_perf_df
# Out:
# Baseline models using all engineered features, mixed imputation, train-test split of train set:
#
#
#  base_perf_engineered
#
#  dt_clf
# DecisionTreeClassifier()
# Training time: 0.004 s
# Prediction time: 0.001 s
# Confusion matrix:
#  [[18  4]
#  [ 2  2]]
# Precision, recall, f beta score, support:
#  (array([0.9       , 0.33333333]), array([0.81818182, 0.5       ]), array([0.85714286, 0.4       ]), array([22,  4], dtype=int64))
#
#
#  rf_clf
# RandomForestClassifier()
# Training time: 0.116 s
# Prediction time: 0.007 s
# Confusion matrix:
#  [[22  0]
#  [ 4  0]]
# Precision, recall, f beta score, support:
#  (array([0.84615385, 0.        ]), array([1., 0.]), array([0.91666667, 0.        ]), array([22,  4], dtype=int64))
#
#
#  ab_clf
# AdaBoostClassifier()
# Training time: 0.052 s
# Prediction time: 0.005 s
# Confusion matrix:
#  [[20  2]
#  [ 3  1]]
# Precision, recall, f beta score, support:
#  (array([0.86956522, 0.33333333]), array([0.90909091, 0.25      ]), array([0.88888889, 0.28571429]), array([22,  4], dtype=int64))
#
#
#  kn_clf
# KNeighborsClassifier()
# Training time: 0.005 s
# Prediction time: 0.002 s
# Confusion matrix:
#  [[22  0]
#  [ 4  0]]
# Precision, recall, f beta score, support:
#  (array([0.84615385, 0.        ]), array([1., 0.]), array([0.91666667, 0.        ]), array([22,  4], dtype=int64))
#
#
#  gnb_clf
# GaussianNB()
# Training time: 0.002 s
# Prediction time: 0.001 s
# Confusion matrix:
#  [[11 11]
#  [ 2  2]]
# Precision, recall, f beta score, support:
#  (array([0.84615385, 0.15384615]), array([0.5, 0.5]), array([0.62857143, 0.23529412]), array([22,  4], dtype=int64))
#
#
#  svc_clf
# SVC()
# Training time: 0.002 s
# Prediction time: 0.001 s
# Confusion matrix:
#  [[22  0]
#  [ 4  0]]
# Precision, recall, f beta score, support:
#  (array([0.84615385, 0.        ]), array([1., 0.]), array([0.91666667, 0.        ]), array([22,  4], dtype=int64))
# C:\Users\kaleb\anaconda3\envs\py3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kaleb\anaconda3\envs\py3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kaleb\anaconda3\envs\py3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
################################################################################################
### [Task 5: Tune your classifier to achieve better than .3 precision and recall 
### using our testing script. Check the tester.py script in the final project
### folder for details on the evaluation method, especially the test_classifier
### function. Because of the small size of the dataset, the script uses
### stratified shuffle split cross validation. For more info: 
### http://scikit-learn.org/stable/modules/generated/sklearn.cross_validation.StratifiedShuffleSplit.html]

### Because the proliferation of features has led to overfit
### (see gridsearch notebooks in the supplemental material folder),
### remove quantile flags, outlier flags, sign flags, and cluster flags,
### leaving the original base features (that were not removed) and the ratio features.

drop_lst = []#quant_flags_lst + out_flags_lst + sign_flags_lst + k_means_feats_lst
keep_lst = [feat for feat in features_list[1:] if feat not in drop_lst]

# X_train_trimmed = X_train_scaled_imp_k[keep_lst]
# X_test_trimmed = X_test_scaled_imp_k[keep_lst]
# data_df_trimmed = data_df_scaled_imp_k[['poi'] + keep_lst]
X_train_trimmed = X_train_scaled_imp[keep_lst]
X_test_trimmed = X_test_scaled_imp[keep_lst]
data_df_trimmed = data_df_scaled_imp[['poi'] + keep_lst]

print('Tuning model.')
### GridSearchCV inputs:
n_jobs = -1
### Callables to pass into parameter grid:
mutual_info_classif_partial = partial(mutual_info_classif, random_state=42)
DecisionTreeClassifier_partial = partial(DecisionTreeClassifier, random_state=42)
RandomForestClassifier_partial = partial(RandomForestClassifier, random_state=42, n_jobs=n_jobs)
AdaBoostClassifier_partial = partial(AdaBoostClassifier, random_state=42)
svm_SVC_partial = partial(svm.SVC, random_state=42)
KNeighborsClassifier_partial = partial(KNeighborsClassifier, n_jobs=n_jobs)

### Would be ideal to scale in the pipeline, but I initially experimented with iterative imputation
### and feeding bools into sklearn, and so scaled first. Not worth rewriting for this project.

selectors = {
    'sel_per': {
        'sel': SelectPercentile(),
        'params': {
            'sel_per__score_func': [f_classif, chi2, mutual_info_classif_partial],
            'sel_per__percentile': [2, 4, 6, 8, 10, 12, 14]
        }
    }
}

decomps = {
    'empty' : None
#     'fica': {
#         'dec': FastICA(),
#         'params': {
#             'fica__algorithm': ['parallel', 'deflation'],
#             'fica__fun': ['logcosh', 'exp', 'cube'],
#             'fica__random_state': [42]
#         }
#     },
#         'ipca': {
#         'dec': IncrementalPCA(),
#         'params': {
#             ### defaults
#         }
#     },
#     'kpca': {
#         'dec': KernelPCA(),
#         'params': {
#             'kpca__kernel': ['linear', 'poly', 'rbf', 'sigmoid', 'cosine',
#                              'precomputed'],
#             'kpca__random_state': [42],
#             'kpca__n_jobs': [n_jobs]
#         }
#     },
    ### PCA kept throwing an error that the data contained nans, inf,
    ### or too large dtypes, despite no nans, infs, nor wrong types per
    ### replications of the sklearn (and numpy) condition checks that threw the
    ### errors ("errors" because using PCA threw the error from sklearn script,
    ### but further investigation showed that PCA's get_precision method (or another method) may have
    ### thrown it from a NumPy script (see gridsearch notebook for tracing), and that
    ### did not include dtype size).
    ### Maybe a problem with the transformed data handed off from
    ### SelectPercentile, but I'm done messing around with it. Just need to finish. Skip PCA.
#     'pca': {
#         'dec': PCA(),
#         'params': {
#             'pca__random_state': [42]
#         }
#     },
#     'tsvd': {
#         'dec': TruncatedSVD(),
#         'params': {
#             'tsvd__n_components': [2, 4, 8, 16, 32, 64, 128],
#             'tsvd__algorithm': ['arpack', 'randomized'],
#             'tsvd__random_state': [42]
#         }
#     }
}

classifiers = {
#     'dt_clf': {
#         'clf': DecisionTreeClassifier(),
#         'params': {
#             'dt_clf__random_state': [42]
#         }
#     },
    'rf_clf': {
        'clf': RandomForestClassifier(),
        'params': {
            'rf_clf__n_estimators': [1, 2, 3, 4, 5, 6, 7],
            'rf_clf__max_features': ['sqrt', 'log2'],
            'rf_clf__max_depth': [8, 16, 24],
            'rf_clf__min_samples_split': [2],
            'rf_clf__min_samples_leaf': [1, 2, 3, 4],
            'rf_clf__bootstrap': [True, False],
            'rf_clf__random_state': [42],
            'rf_clf__n_jobs': [n_jobs]
        }
    },
#     'ab_clf': {
#         'clf': AdaBoostClassifier(),
#         'params': {
#             'ab_clf__base_estimator': [
#                 DecisionTreeClassifier_partial(),
#                 RandomForestClassifier_partial(),
#                 AdaBoostClassifier_partial(),
#                 svm_SVC_partial(),
#                 KNeighborsClassifier_partial(),
#                 GaussianNB()
#             ],
#             'ab_clf__n_estimators': [8, 16, 24, 32, 40, 48, 56],
#             'ab_clf__algorithm': ['SAMME', 'SAMME.R'],
#             'ab_clf__random_state': [42]
#         }
#     },
#     'kn_clf': {
#         'clf': KNeighborsClassifier(),
#         'params': {
#             'kn_clf__n_neighbors': [2, 3, 4, 5, 6, 7, 8, 9, 10],
#             'kn_clf__weights': ['uniform', 'distance'],
#             'kn_clf__algorithm': ['ball_tree', 'kd_tree', 'brute'],
#             'kn_clf__leaf_size': [4, 8, 12, 16, 20, 24, 30],
#             'kn_clf__n_jobs': [n_jobs]
#         }
#     },
#     'gnb_clf': {
#         'clf': GaussianNB(),
#         'params': {
#             # Defaults
#         }
#     },
}


print('\nGrid search output:\n')
imp_gscvs_dict = {}
imp_gscvs_dict['mixed_impute_trimmed'] \
    = search_em_all(X_train=X_train_trimmed, y_train=y_train_1d, selectors=selectors,
                    decomps=decomps, classifiers=classifiers, pipe_verbose=True,
                    scoring='recall_weighted', n_jobs=-1)
### Can try with multiple datasets for comparison.
# imp_gscvs_dict['other_set'] \
#     = search_em_all(X_train=X_train_other_set, y_train=y_train_1d, selectors=selectors,
#                     decomps=decomps, classifiers=classifiers, pipe_verbose=True,
#                     scoring='recall_weighted', n_jobs=-1)
# Out:
# Tuning model.
#
# Grid search output:
#
#
#  0 sel_per_empty_rf_clf
#
# Fitting 5 folds for each of 7056 candidates, totalling 35280 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 288 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 1568 tasks      | elapsed:   17.5s
# [Parallel(n_jobs=-1)]: Done 3360 tasks      | elapsed:   35.6s
# [Parallel(n_jobs=-1)]: Done 5664 tasks      | elapsed:   58.8s
# [Parallel(n_jobs=-1)]: Done 8480 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 11808 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done 15648 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 20000 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done 24864 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 30240 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done 35280 out of 35280 | elapsed:  5.9min finished
# [Pipeline] ........... (step 1 of 2) Processing sel_per, total=   0.1s
# [Pipeline] ............ (step 2 of 2) Processing rf_clf, total=   0.0s
#
#  GridSearchCV(estimator=Pipeline(steps=[('sel_per', SelectPercentile()),
#                                        ('rf_clf', RandomForestClassifier())],
#                                 verbose=True),
#              n_jobs=-1,
#              param_grid={'rf_clf__bootstrap': [True, False],
#                          'rf_clf__max_depth': [8, 16, 24],
#                          'rf_clf__max_features': ['sqrt', 'log2'],
#                          'rf_clf__min_samples_leaf': [1, 2, 3, 4],
#                          'rf_clf__min_samples_split': [2],
#                          'rf_clf__n_estimators': [1, 2, 3, 4, 5, 6, 7],
#                          'rf_clf__n_jobs': [-1], 'rf_clf__random_state': [42],
#                          'sel_per__percentile': [2, 4, 6, 8, 10, 12, 14],
#                          'sel_per__score_func': [<function f_classif at 0x0000025AB1A748B0>,
#                                                  <function chi2 at 0x0000025AB1A74C10>,
#                                                  functools.partial(<function mutual_info_classif at 0x0000025AB1A8E790>, random_state=42)]},
#              scoring='recall_weighted', verbose=3)
#
# best_score_: 0.8718954248366014
#
# best_params_: {'rf_clf__bootstrap': False, 'rf_clf__max_depth': 8, 'rf_clf__max_features': 'sqrt', 'rf_clf__min_samples_leaf': 2, 'rf_clf__min_samples_split': 2, 'rf_clf__n_estimators': 4, 'rf_clf__n_jobs': -1, 'rf_clf__random_state': 42, 'sel_per__percentile': 8, 'sel_per__score_func': functools.partial(<function mutual_info_classif at 0x0000025AB1A8E790>, random_state=42)}

# %%
with open('data/imp_gscvs_dict_last.pkl', 'wb') as file:
    pickle.dump(obj=imp_gscvs_dict, file=file)

# %%
### Check some performance metrics of final model.
get_f = lambda precision, recall: 2 * ((precision * recall) / (precision + recall))
for name, gscv in imp_gscvs_dict['mixed_impute_trimmed'].items():
    print('Best model key:', name, '\n')
    print('Best score:\n', gscv.best_score_, '\n')
    print('Best estimator:\n', gscv.best_estimator_, '\n')
    clf = gscv.best_estimator_
    pred = clf.predict(X_test_trimmed)
    conf = confusion_matrix(y_true=y_test_1d, y_pred=pred)
    print('Confusion matrix:\n', conf, '\n')
    prf = precision_recall_fscore_support(y_true=y_test_1d, y_pred=pred)
    print('Precision, recall, f beta score, support:\n', prf, '\n')
    print('Custom F beta using nonPOI precision and POI recall:\n', get_f(prf[0][0], prf[1][1]), '\n')
    print('\n')
# Out:
# Best model key: sel_per_empty_rf_clf
#
# Best score:
#  0.8718954248366014
#
# Best estimator:
#  Pipeline(steps=[('sel_per',
#                  SelectPercentile(percentile=8,
#                                   score_func=functools.partial(<function mutual_info_classif at 0x0000025AB1A8E790>, random_state=42))),
#                 ('rf_clf',
#                  RandomForestClassifier(bootstrap=False, max_depth=8,
#                                         max_features='sqrt', min_samples_leaf=2,
#                                         n_estimators=4, n_jobs=-1,
#                                         random_state=42))],
#          verbose=True)
#
# Confusion matrix:
#  [[30  4]
#  [ 1  2]]
#
# Precision, recall, f beta score, support:
#  (array([0.96774194, 0.33333333]), array([0.88235294, 0.66666667]), array([0.92307692, 0.44444444]), array([34,  3], dtype=int64))
#
# Custom F beta using nonPOI precision and POI recall:
#  0.7894736842105263

# %%
### Check final features.
print('\nAll features and their scores provided by scoring function mutual_info_classif:')
feature_scores_sr = pd.Series(data=clf.named_steps['sel_per'].scores_, index=X_train_trimmed.columns)
print(feature_scores_sr.sort_values(ascending=False))

print('\nSelected features and their scores provided by selecting function mutual_info_classif:')
num_selected = int((0.01 * clf.named_steps['sel_per'].percentile) * len(X_train_trimmed.columns))
print(feature_scores_sr.sort_values(ascending=False).head(num_selected))
# Out:
# All features and their scores provided by scoring function mutual_info_classif:
# deferred_income_DivBy_total_payments                     0.119102
# from_this_person_to_poi_DivBy_from_messages              0.096761
# expenses                                                 0.093968
# expenses_DivBy_bonus                                     0.079620
# expenses_DivBy_salary                                    0.069812
# salary_DivBy_expenses                                    0.054408
# total_payments_DivBy_long_term_incentive                 0.047625
# from_this_person_to_poi                                  0.046734
# expenses_DivBy_long_term_incentive                       0.045198
# from_messages_DivBy_from_this_person_to_poi              0.041893
# salary_DivBy_bonus                                       0.041637
# from_poi_to_this_person_DivBy_to_messages                0.039296
# bonus_DivBy_expenses                                     0.037907
# restricted_stock_DivBy_total_stock_value                 0.036282
# bonus                                                    0.035839
# shared_receipt_with_poi                                  0.034999
# salary_DivBy_total_payments                              0.034852
# shared_receipt_with_poi_DivBy_from_poi_to_this_person    0.033844
# from_poi_to_this_person                                  0.032920
# expenses_DivBy_total_payments                            0.032550
# total_payments                                           0.029850
# bonus_DivBy_salary                                       0.026557
# from_poi_to_this_person_DivBy_shared_receipt_with_poi    0.021062
# total_payments_DivBy_deferred_income                     0.018785
# salary                                                   0.013726
# restricted_stock                                         0.013188
# to_messages_DivBy_shared_receipt_with_poi                0.011121
# total_payments_DivBy_salary                              0.007416
# total_payments_DivBy_expenses                            0.006358
# long_term_incentive_DivBy_expenses                       0.002260
# total_stock_value                                        0.000000
# long_term_incentive                                      0.000000
# deferred_income                                          0.000000
# shared_receipt_with_poi_DivBy_to_messages                0.000000
# exercised_stock_options                                  0.000000
# to_messages_DivBy_from_poi_to_this_person                0.000000
# total_stock_value_DivBy_restricted_stock                 0.000000
# total_stock_value_DivBy_exercised_stock_options          0.000000
# exercised_stock_options_DivBy_total_stock_value          0.000000
# restricted_stock_DivBy_exercised_stock_options           0.000000
# long_term_incentive_DivBy_bonus                          0.000000
# exercised_stock_options_DivBy_restricted_stock           0.000000
# to_messages                                              0.000000
# from_messages                                            0.000000
# total_payments_DivBy_bonus                               0.000000
# salary_DivBy_long_term_incentive                         0.000000
# bonus_DivBy_long_term_incentive                          0.000000
# bonus_DivBy_total_payments                               0.000000
# long_term_incentive_DivBy_salary                         0.000000
# long_term_incentive_DivBy_total_payments                 0.000000
# dtype: float64
#
# Selected features and their scores provided by selecting function mutual_info_classif:
# deferred_income_DivBy_total_payments           0.119102
# from_this_person_to_poi_DivBy_from_messages    0.096761
# expenses                                       0.093968
# expenses_DivBy_bonus                           0.079620
# dtype: float64

# %%
y_train_base.shape
y_test_base.shape
# Out:
# (60, 1)
# (26, 1)

# %%
### Compare to baseline using whole set.
### Store metrics in a dataframe in case you want to save and inspect it.
base_perf_full_df= pd.DataFrame(columns=ordered_cols_lst)
print('\nBaseline models, no engineered features, no tuning, impute with 0, full train-test split:\n')
for key, method in clf_dict.items():
    _, _, _, prf, perf_sr = run_skl(method=method, X_train=X_train_base,
                                  y_train=y_train_base,
                                  X_test=X_test_base,
                                  y_test=y_test_base,
                                  perf_series=key)
    print('Custom F beta using nonPOI precision and POI recall:\n', get_f(prf[0][0], prf[1][1]), '\n')
    base_perf_full_df = base_perf_full_df.append(perf_sr)
    
print('\nBaseline models, cleaned set, human-selected and engineered features, scaled, mixed imputation, no tuning:\n')
base_perf_engineered_trimmed_df = pd.DataFrame(columns=ordered_cols_lst)
for key, method in clf_dict.items():
    _, _, _, prf, perf_sr = run_skl(method=method, X_train=X_train_trimmed,
                                  y_train=y_train_1d,
                                  X_test=X_test_trimmed,
                                  y_test=y_test_1d,
                                  perf_series=key)
    print('Custom F beta using nonPOI precision and POI recall:\n', get_f(prf[0][0], prf[1][1]), '\n')
    base_perf_full_df = base_perf_df.append(perf_sr)
# Out:
# Baseline models, no engineered features, no tuning, impute with 0, full train-test split:
#
# DecisionTreeClassifier()
# Training time: 0.003 s
# Prediction time: 0.002 s
# Confusion matrix:
#  [[16  6]
#  [ 2  2]]
# Precision, recall, f beta score, support:
#  (array([0.88888889, 0.25      ]), array([0.72727273, 0.5       ]), array([0.8       , 0.33333333]), array([22,  4], dtype=int64))
#
# Custom F beta using nonPOI precision and POI recall:
#  0.64
#
# RandomForestClassifier()
# Training time: 0.099 s
# Prediction time: 0.01 s
# Confusion matrix:
#  [[22  0]
#  [ 3  1]]
# Precision, recall, f beta score, support:
#  (array([0.88, 1.  ]), array([1.  , 0.25]), array([0.93617021, 0.4       ]), array([22,  4], dtype=int64))
#
# Custom F beta using nonPOI precision and POI recall:
#  0.3893805309734514
#
# AdaBoostClassifier()
# Training time: 0.06 s
# Prediction time: 0.005 s
# Confusion matrix:
#  [[20  2]
#  [ 3  1]]
# Precision, recall, f beta score, support:
#  (array([0.86956522, 0.33333333]), array([0.90909091, 0.25      ]), array([0.88888889, 0.28571429]), array([22,  4], dtype=int64))
#
# Custom F beta using nonPOI precision and POI recall:
#  0.38834951456310685
# tools\train_test.py:42: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf = clf.fit(X=X_train, y=y_train)
# C:\Users\kaleb\anaconda3\envs\py3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# tools\train_test.py:42: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   clf = clf.fit(X=X_train, y=y_train)
# C:\Users\kaleb\anaconda3\envs\py3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# KNeighborsClassifier()
# Training time: 0.0 s
# Prediction time: 0.007 s
# Confusion matrix:
#  [[22  0]
#  [ 4  0]]
# Precision, recall, f beta score, support:
#  (array([0.84615385, 0.        ]), array([1., 0.]), array([0.91666667, 0.        ]), array([22,  4], dtype=int64))
#
# Custom F beta using nonPOI precision and POI recall:
#  0.0
#
# GaussianNB()
# Training time: 0.002 s
# Prediction time: 0.002 s
# Confusion matrix:
#  [[11 11]
#  [ 2  2]]
# Precision, recall, f beta score, support:
#  (array([0.84615385, 0.15384615]), array([0.5, 0.5]), array([0.62857143, 0.23529412]), array([22,  4], dtype=int64))
#
# Custom F beta using nonPOI precision and POI recall:
#  0.6285714285714286
#
# SVC()
# Training time: 0.003 s
# Prediction time: 0.001 s
# Confusion matrix:
#  [[22  0]
#  [ 4  0]]
# Precision, recall, f beta score, support:
#  (array([0.84615385, 0.        ]), array([1., 0.]), array([0.91666667, 0.        ]), array([22,  4], dtype=int64))
#
# Custom F beta using nonPOI precision and POI recall:
#  0.0
#
#
# Baseline models, cleaned set, human-selected and engineered features, scaled, mixed imputation, no tuning:
#
# DecisionTreeClassifier()
# Training time: 0.002 s
# Prediction time: 0.001 s
# Confusion matrix:
#  [[30  4]
#  [ 1  2]]
# Precision, recall, f beta score, support:
#  (array([0.96774194, 0.33333333]), array([0.88235294, 0.66666667]), array([0.92307692, 0.44444444]), array([34,  3], dtype=int64))
#
# Custom F beta using nonPOI precision and POI recall:
#  0.7894736842105263
#
# RandomForestClassifier()
# Training time: 0.097 s
# Prediction time: 0.005 s
# Confusion matrix:
#  [[33  1]
#  [ 2  1]]
# Precision, recall, f beta score, support:
#  (array([0.94285714, 0.5       ]), array([0.97058824, 0.33333333]), array([0.95652174, 0.4       ]), array([34,  3], dtype=int64))
#
# Custom F beta using nonPOI precision and POI recall:
#  0.49253731343283585
#
# AdaBoostClassifier()
# Training time: 0.055 s
# Prediction time: 0.005 s
# Confusion matrix:
#  [[31  3]
#  [ 1  2]]
# Precision, recall, f beta score, support:
#  (array([0.96875, 0.4    ]), array([0.91176471, 0.66666667]), array([0.93939394, 0.5       ]), array([34,  3], dtype=int64))
#
# Custom F beta using nonPOI precision and POI recall:
#  0.7898089171974522
# C:\Users\kaleb\anaconda3\envs\py3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\kaleb\anaconda3\envs\py3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# C:\Users\kaleb\anaconda3\envs\py3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# KNeighborsClassifier()
# Training time: 0.0 s
# Prediction time: 0.006 s
# Confusion matrix:
#  [[34  0]
#  [ 3  0]]
# Precision, recall, f beta score, support:
#  (array([0.91891892, 0.        ]), array([1., 0.]), array([0.95774648, 0.        ]), array([34,  3], dtype=int64))
#
# Custom F beta using nonPOI precision and POI recall:
#  0.0
#
# GaussianNB()
# Training time: 0.0 s
# Prediction time: 0.0 s
# Confusion matrix:
#  [[21 13]
#  [ 0  3]]
# Precision, recall, f beta score, support:
#  (array([1.    , 0.1875]), array([0.61764706, 1.        ]), array([0.76363636, 0.31578947]), array([34,  3], dtype=int64))
#
# Custom F beta using nonPOI precision and POI recall:
#  1.0
#
# SVC()
# Training time: 0.0 s
# Prediction time: 0.0 s
# Confusion matrix:
#  [[34  0]
#  [ 3  0]]
# Precision, recall, f beta score, support:
#  (array([0.91891892, 0.        ]), array([1., 0.]), array([0.95774648, 0.        ]), array([34,  3], dtype=int64))
#
# Custom F beta using nonPOI precision and POI recall:
#  0.0
# C:\Users\kaleb\anaconda3\envs\py3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\kaleb\anaconda3\envs\py3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
### [Task 6: Dump your classifier, dataset, and features_list so anyone can
### check your results ...]
print('Saving classifier, data, and features list.')
features_list = keep_lst
data_df_trimmed['poi'] = data_df_trimmed['poi'].astype(bool)
my_dataset = data_df_trimmed.T.to_dict()
### Would be ideal to scale in the pipeline, but I initially experimented with iterative imputation
### and feeding bools into sklearn, and so scaled first. Not worth rewriting for this project.
clf = imp_gscvs_dict['mixed_impute_trimmed']['sel_per_empty_rf_clf'].best_estimator_

CLF_PICKLE_FILENAME = "my_classifier.pkl"
DATASET_PICKLE_FILENAME = "my_dataset.pkl"
FEATURE_LIST_FILENAME = "my_feature_list.pkl"

with open(CLF_PICKLE_FILENAME, "wb") as clf_outfile:
    pickle.dump(clf, clf_outfile)
with open(DATASET_PICKLE_FILENAME, "wb") as dataset_outfile:
    pickle.dump(my_dataset, dataset_outfile)
with open(FEATURE_LIST_FILENAME, "wb") as featurelist_outfile:
    pickle.dump(features_list, featurelist_outfile)
    
### [... You do not need to change anything below, but make sure
### that the version of poi_id.py that you submit can be run on its own and
### generates the necessary .pkl files for validating your results.]

### Deprecated
# dump_classifier_and_data(clf, my_dataset, features_list)
# Out:
# Saving classifier, data, and features list.

# %%
unpickled_data_dict = {}
with open('my_dataset.pkl', 'rb') as file:
    unpickled_data_dict = pickle.load(file=file)
unpickled_data_dict
# Out:
# {'ALLEN PHILLIP K': {'poi': False,
#   'salary': 0.13703564527051476,
#   'bonus': 0.5176544766708702,
#   'long_term_incentive': 0.10878617035572011,
#   'deferred_income': 0.011554329869112312,
#   'expenses': 0.05815140929949203,
#   'total_payments': 0.42586365927041875,
#   'exercised_stock_options': 0.049872205900403845,
#   'restricted_stock': 0.0055670757754609605,
#   'total_stock_value': 0.03521763903531165,
#   'to_messages': 0.23821485388930755,
#   'from_poi_to_this_person': 0.08901515151515152,
#   'from_messages': 0.2732849273910866,
#   'from_this_person_to_poi': 0.10673234811165845,
#   'shared_receipt_with_poi': 0.2545751041855408,
#   'salary_DivBy_bonus': 0.0024421365831252817,
#   'salary_DivBy_long_term_incentive': 0.15330045337626158,
#   'salary_DivBy_expenses': 0.032534846169570024,
#   'salary_DivBy_total_payments': 0.013645667077033026,
#   'bonus_DivBy_salary': 0.8406060077318622,
#   'bonus_DivBy_long_term_incentive': 0.5561277171970658,
#   'bonus_DivBy_expenses': 0.35935258937133757,
#   'bonus_DivBy_total_payments': 0.1672694590769606,
#   'long_term_incentive_DivBy_salary': 0.10421226044940905,
#   'long_term_incentive_DivBy_bonus': 0.0029001470525473728,
#   'long_term_incentive_DivBy_expenses': 0.04220213413776545,
#   'long_term_incentive_DivBy_total_payments': 0.00623512964302137,
#   'deferred_income_DivBy_total_payments': 0.9365342966484625,
#   'expenses_DivBy_salary': 0.076497276936829,
#   'expenses_DivBy_bonus': 0.005289079959738641,
#   'expenses_DivBy_long_term_incentive': 0.024568006295781215,
#   'expenses_DivBy_total_payments': 0.0029499464438905096,
#   'total_payments_DivBy_salary': 0.712767123523385,
#   'total_payments_DivBy_bonus': 0.06644450916817606,
#   'total_payments_DivBy_long_term_incentive': 0.4861633456421838,
#   'total_payments_DivBy_deferred_income': 0.9973938530018175,
#   'total_payments_DivBy_expenses': 0.18342553153805394,
#   'exercised_stock_options_DivBy_restricted_stock': 0.20999347017905695,
#   'exercised_stock_options_DivBy_total_stock_value': 1.0,
#   'restricted_stock_DivBy_exercised_stock_options': 0.005392147797224498,
#   'restricted_stock_DivBy_total_stock_value': 0.05860373003366433,
#   'total_stock_value_DivBy_exercised_stock_options': 0.0,
#   'total_stock_value_DivBy_restricted_stock': 0.20793295616547777,
#   'to_messages_DivBy_from_poi_to_this_person': 0.06135246112288196,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.019891627221592066,
#   'from_poi_to_this_person_DivBy_to_messages': 0.07451757408683668,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.10438877043354655,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.4751938251203377,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.03724420241398292,
#   'from_messages_DivBy_from_this_person_to_poi': 0.30769230769230765,
#   'from_this_person_to_poi_DivBy_from_messages': 0.029612756264236904},
#  'BADUM JAMES P': {'poi': False,
#   'salary': 0.0,
#   'bonus': 0.0,
#   'long_term_incentive': 0.0,
#   'deferred_income': 0.0,
#   'expenses': 0.01264885191726967,
#   'total_payments': 0.010144115946006407,
#   'exercised_stock_options': 0.007003552415562771,
#   'restricted_stock': 0.0,
#   'total_stock_value': 0.005249777856186667,
#   'to_messages': 0.10575232353679981,
#   'from_poi_to_this_person': 0.07196969696969698,
#   'from_messages': 0.003505257886830245,
#   'from_this_person_to_poi': 0.0180623973727422,
#   'shared_receipt_with_poi': 0.1395180286283747,
#   'salary_DivBy_bonus': 0.0,
#   'salary_DivBy_long_term_incentive': 0.0,
#   'salary_DivBy_expenses': 0.0,
#   'salary_DivBy_total_payments': 0.0,
#   'bonus_DivBy_salary': 0.0,
#   'bonus_DivBy_long_term_incentive': 0.0,
#   'bonus_DivBy_expenses': 0.0,
#   'bonus_DivBy_total_payments': 0.0,
#   'long_term_incentive_DivBy_salary': 0.0,
#   'long_term_incentive_DivBy_bonus': 0.0,
#   'long_term_incentive_DivBy_expenses': 0.0,
#   'long_term_incentive_DivBy_total_payments': 0.0,
#   'deferred_income_DivBy_total_payments': 0.0,
#   'expenses_DivBy_salary': 0.0,
#   'expenses_DivBy_bonus': 0.0,
#   'expenses_DivBy_long_term_incentive': 0.0,
#   'expenses_DivBy_total_payments': 0.021667957105242802,
#   'total_payments_DivBy_salary': 0.0,
#   'total_payments_DivBy_bonus': 0.0,
#   'total_payments_DivBy_long_term_incentive': 0.0,
#   'total_payments_DivBy_deferred_income': 0.0,
#   'total_payments_DivBy_expenses': 0.029133260591629125,
#   'exercised_stock_options_DivBy_restricted_stock': 0.0,
#   'exercised_stock_options_DivBy_total_stock_value': 1.0,
#   'restricted_stock_DivBy_exercised_stock_options': 0.0,
#   'restricted_stock_DivBy_total_stock_value': 0.0,
#   'total_stock_value_DivBy_exercised_stock_options': 0.0,
#   'total_stock_value_DivBy_restricted_stock': 0.0,
#   'to_messages_DivBy_from_poi_to_this_person': 0.03049062551755253,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.008891686139548584,
#   'from_poi_to_this_person_DivBy_to_messages': 0.13427506985408258,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.14275517487508924,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.6719541332574738,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.021224872817015364,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03442879499217527,
#   'from_this_person_to_poi_DivBy_from_messages': 0.12121212121212122},
#  'BANNANTINE JAMES M': {'poi': False,
#   'salary': 0.0,
#   'bonus': 0.0,
#   'long_term_incentive': 0.0,
#   'deferred_income': 0.9999999999999999,
#   'expenses': 0.24412810140119123,
#   'total_payments': 0.08104788580501177,
#   'exercised_stock_options': 0.11735103247484213,
#   'restricted_stock': 0.11642243868413066,
#   'total_stock_value': 0.10677008087830771,
#   'to_messages': 0.04261910742694466,
#   'from_poi_to_this_person': 0.07386363636363637,
#   'from_messages': 0.0021281922884326485,
#   'from_this_person_to_poi': 0.0,
#   'shared_receipt_with_poi': 0.08389200942199673,
#   'salary_DivBy_bonus': 0.0,
#   'salary_DivBy_long_term_incentive': 0.0,
#   'salary_DivBy_expenses': 0.0,
#   'salary_DivBy_total_payments': 0.0,
#   'bonus_DivBy_salary': 0.0,
#   'bonus_DivBy_long_term_incentive': 0.0,
#   'bonus_DivBy_expenses': 0.0,
#   'bonus_DivBy_total_payments': 0.0,
#   'long_term_incentive_DivBy_salary': 0.0,
#   'long_term_incentive_DivBy_bonus': 0.0,
#   'long_term_incentive_DivBy_expenses': 0.0,
#   'long_term_incentive_DivBy_total_payments': 0.0,
#   'deferred_income_DivBy_total_payments': 0.9996610663448176,
#   'expenses_DivBy_salary': 0.0,
#   'expenses_DivBy_bonus': 0.0,
#   'expenses_DivBy_long_term_incentive': 0.0,
#   'expenses_DivBy_total_payments': 0.0711687639923216,
#   'total_payments_DivBy_salary': 0.0,
#   'total_payments_DivBy_bonus': 0.0,
#   'total_payments_DivBy_long_term_incentive': 0.0,
#   'total_payments_DivBy_deferred_income': 0.656918548135341,
#   'total_payments_DivBy_expenses': 0.008599195357098747,
#   'exercised_stock_options_DivBy_restricted_stock': 0.03402573180611544,
#   'exercised_stock_options_DivBy_total_stock_value': 0.7502647864220391,
#   'restricted_stock_DivBy_exercised_stock_options': 0.039303332971356096,
#   'restricted_stock_DivBy_total_stock_value': 0.32495975116734926,
#   'total_stock_value_DivBy_exercised_stock_options': 0.02771848592090262,
#   'total_stock_value_DivBy_restricted_stock': 0.045203085158944216,
#   'to_messages_DivBy_from_poi_to_this_person': 0.010641795151483734,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.004066227165215642,
#   'from_poi_to_this_person_DivBy_to_messages': 0.31703443350124055,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.26209677419354843,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.8182141419932415,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.012221673100297861,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03442879499217527,
#   'from_this_person_to_poi_DivBy_from_messages': 0.0},
#  'BAXTER JOHN C': {'poi': False,
#   'salary': 0.2016286312299408,
#   'bonus': 0.14249684741488022,
#   'long_term_incentive': 0.7004369788566513,
#   'deferred_income': 0.5562364170908706,
#   'expenses': 0.04645801466495444,
#   'total_payments': 0.5369838325555057,
#   'exercised_stock_options': 0.19408595250602326,
#   'restricted_stock': 0.26489514153835264,
#   'total_stock_value': 0.21631523370824213,
#   'to_messages': 0.10575232353679981,
#   'from_poi_to_this_person': 0.07196969696969698,
#   'from_messages': 0.003505257886830245,
#   'from_this_person_to_poi': 0.0180623973727422,
#   'shared_receipt_with_poi': 0.1395180286283747,
#   'salary_DivBy_bonus': 0.05834356249442811,
#   'salary_DivBy_long_term_incentive': 0.022916878970758812,
#   'salary_DivBy_expenses': 0.05506153429173177,
#   'salary_DivBy_total_payments': 0.016236286272962953,
#   'bonus_DivBy_salary': 0.17244440538246414,
#   'bonus_DivBy_long_term_incentive': 0.027263258460995303,
#   'bonus_DivBy_expenses': 0.12596459096459095,
#   'bonus_DivBy_total_payments': 0.02707951157276082,
#   'long_term_incentive_DivBy_salary': 0.47314540464849286,
#   'long_term_incentive_DivBy_bonus': 0.11506114806252192,
#   'long_term_incentive_DivBy_expenses': 0.277958010723544,
#   'long_term_incentive_DivBy_total_payments': 0.04458360014562071,
#   'deferred_income_DivBy_total_payments': 0.9773896665219913,
#   'expenses_DivBy_salary': 0.04562425986549897,
#   'expenses_DivBy_bonus': 0.02027540360873694,
#   'expenses_DivBy_long_term_incentive': 0.0028745279575151743,
#   'expenses_DivBy_total_payments': 0.001658637086297581,
#   'total_payments_DivBy_salary': 0.6753327991959159,
#   'total_payments_DivBy_bonus': 0.3393454715162189,
#   'total_payments_DivBy_long_term_incentive': 0.1128573835180121,
#   'total_payments_DivBy_deferred_income': 0.9924037924444628,
#   'total_payments_DivBy_expenses': 0.2857278484247226,
#   'exercised_stock_options_DivBy_restricted_stock': 0.024662199142234345,
#   'exercised_stock_options_DivBy_total_stock_value': 0.5940956915527662,
#   'restricted_stock_DivBy_exercised_stock_options': 0.053918384658959415,
#   'restricted_stock_DivBy_total_stock_value': 0.3614650420803109,
#   'total_stock_value_DivBy_exercised_stock_options': 0.055281754292246854,
#   'total_stock_value_DivBy_restricted_stock': 0.040824278541495666,
#   'to_messages_DivBy_from_poi_to_this_person': 0.03049062551755253,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.008891686139548584,
#   'from_poi_to_this_person_DivBy_to_messages': 0.13427506985408258,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.14275517487508924,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.6719541332574738,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.021224872817015364,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03442879499217527,
#   'from_this_person_to_poi_DivBy_from_messages': 0.12121212121212122},
#  'BAY FRANKLIN R': {'poi': False,
#   'salary': 0.17443090611822398,
#   'bonus': 0.0416141235813367,
#   'long_term_incentive': 0.0,
#   'deferred_income': 0.9368435496304999,
#   'expenses': 0.5633779359492994,
#   'total_payments': 0.07249563091010909,
#   'exercised_stock_options': 0.0,
#   'restricted_stock': 0.006910297405127372,
#   'total_stock_value': 0.0012831174896525313,
#   'to_messages': 0.10575232353679981,
#   'from_poi_to_this_person': 0.07196969696969698,
#   'from_messages': 0.003505257886830245,
#   'from_this_person_to_poi': 0.0180623973727422,
#   'shared_receipt_with_poi': 0.1395180286283747,
#   'salary_DivBy_bonus': 0.1791847897915571,
#   'salary_DivBy_long_term_incentive': 0.0,
#   'salary_DivBy_expenses': 0.0017088491001729937,
#   'salary_DivBy_total_payments': 0.28077213311165583,
#   'bonus_DivBy_salary': 0.05583961589480119,
#   'bonus_DivBy_long_term_incentive': 0.0,
#   'bonus_DivBy_expenses': 0.0007365045857557974,
#   'bonus_DivBy_total_payments': 0.079852485501894,
#   'long_term_incentive_DivBy_salary': 0.0,
#   'long_term_incentive_DivBy_bonus': 0.0,
#   'long_term_incentive_DivBy_expenses': 0.0,
#   'long_term_incentive_DivBy_total_payments': 0.0,
#   'deferred_income_DivBy_total_payments': 0.9776104954988472,
#   'expenses_DivBy_salary': 0.6193849702725505,
#   'expenses_DivBy_bonus': 0.8018465099715099,
#   'expenses_DivBy_long_term_incentive': 0.0,
#   'expenses_DivBy_total_payments': 0.18172381017904948,
#   'total_payments_DivBy_salary': 0.08083189788415833,
#   'total_payments_DivBy_bonus': 0.1414395921813319,
#   'total_payments_DivBy_long_term_incentive': 0.0,
#   'total_payments_DivBy_deferred_income': 0.992327725532973,
#   'total_payments_DivBy_expenses': 0.0029836749588467424,
#   'exercised_stock_options_DivBy_restricted_stock': 0.0,
#   'exercised_stock_options_DivBy_total_stock_value': 0.0,
#   'restricted_stock_DivBy_exercised_stock_options': 0.0,
#   'restricted_stock_DivBy_total_stock_value': 2.3339189581802335,
#   'total_stock_value_DivBy_exercised_stock_options': 0.0,
#   'total_stock_value_DivBy_restricted_stock': 0.006548585528804465,
#   'to_messages_DivBy_from_poi_to_this_person': 0.03049062551755253,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.008891686139548584,
#   'from_poi_to_this_person_DivBy_to_messages': 0.13427506985408258,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.14275517487508924,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.6719541332574738,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.021224872817015364,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03442879499217527,
#   'from_this_person_to_poi_DivBy_from_messages': 0.12121212121212122},
#  'BAZELIDES PHILIP J': {'poi': False,
#   'salary': 0.01692880166809277,
#   'bonus': 0.0,
#   'long_term_incentive': 0.011325985857640851,
#   'deferred_income': 0.0,
#   'expenses': 0.0,
#   'total_payments': 0.07563045592666984,
#   'exercised_stock_options': 0.04608845426784173,
#   'restricted_stock': 0.0,
#   'total_stock_value': 0.03257256076848422,
#   'to_messages': 0.10575232353679981,
#   'from_poi_to_this_person': 0.07196969696969698,
#   'from_messages': 0.003505257886830245,
#   'from_this_person_to_poi': 0.0180623973727422,
#   'shared_receipt_with_poi': 0.1395180286283747,
#   'salary_DivBy_bonus': 0.0,
#   'salary_DivBy_long_term_incentive': 0.2059345218956669,
#   'salary_DivBy_expenses': 0.0,
#   'salary_DivBy_total_payments': 0.0670918040579055,
#   'bonus_DivBy_salary': 0.0,
#   'bonus_DivBy_long_term_incentive': 0.0,
#   'bonus_DivBy_expenses': 0.0,
#   'bonus_DivBy_total_payments': 0.0,
#   'long_term_incentive_DivBy_salary': 0.07511756564312426,
#   'long_term_incentive_DivBy_bonus': 0.0,
#   'long_term_incentive_DivBy_expenses': 0.0,
#   'long_term_incentive_DivBy_total_payments': 0.013602977326949262,
#   'deferred_income_DivBy_total_payments': 0.0,
#   'expenses_DivBy_salary': 0.0,
#   'expenses_DivBy_bonus': 0.0,
#   'expenses_DivBy_long_term_incentive': 0.0,
#   'expenses_DivBy_total_payments': 0.0,
#   'total_payments_DivBy_salary': 0.32311627693502076,
#   'total_payments_DivBy_bonus': 0.0,
#   'total_payments_DivBy_long_term_incentive': 0.3009260942585434,
#   'total_payments_DivBy_deferred_income': 0.0,
#   'total_payments_DivBy_expenses': 0.0,
#   'exercised_stock_options_DivBy_restricted_stock': 0.0,
#   'exercised_stock_options_DivBy_total_stock_value': 1.0,
#   'restricted_stock_DivBy_exercised_stock_options': 0.0,
#   'restricted_stock_DivBy_total_stock_value': 0.0,
#   'total_stock_value_DivBy_exercised_stock_options': 0.0,
#   'total_stock_value_DivBy_restricted_stock': 0.0,
#   'to_messages_DivBy_from_poi_to_this_person': 0.03049062551755253,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.008891686139548584,
#   'from_poi_to_this_person_DivBy_to_messages': 0.13427506985408258,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.14275517487508924,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.6719541332574738,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.021224872817015364,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03442879499217527,
#   'from_this_person_to_poi_DivBy_from_messages': 0.12121212121212122},
#  'BECK SALLY W': {'poi': False,
#   'salary': 0.16616083848828594,
#   'bonus': 0.07944514501891552,
#   'long_term_incentive': 0.0,
#   'deferred_income': 0.0,
#   'expenses': 0.16028891625723715,
#   'total_payments': 0.08615705144775478,
#   'exercised_stock_options': 0.0,
#   'restricted_stock': 0.0055670757754609605,
#   'total_stock_value': 0.0025662146168857645,
#   'to_messages': 0.6077200033492423,
#   'from_poi_to_this_person': 0.2727272727272727,
#   'from_messages': 0.5421882824236354,
#   'from_this_person_to_poi': 0.6338259441707718,
#   'shared_receipt_with_poi': 0.47780394999094034,
#   'salary_DivBy_bonus': 0.09296222440956309,
#   'salary_DivBy_long_term_incentive': 0.0,
#   'salary_DivBy_expenses': 0.012303833676117256,
#   'salary_DivBy_total_payments': 0.2252229174058389,
#   'bonus_DivBy_salary': 0.11187781605556253,
#   'bonus_DivBy_long_term_incentive': 0.0,
#   'bonus_DivBy_expenses': 0.019673800976932367,
#   'bonus_DivBy_total_payments': 0.12653079075737622,
#   'long_term_incentive_DivBy_salary': 0.0,
#   'long_term_incentive_DivBy_bonus': 0.0,
#   'long_term_incentive_DivBy_expenses': 0.0,
#   'long_term_incentive_DivBy_total_payments': 0.0,
#   'deferred_income_DivBy_total_payments': 0.0,
#   'expenses_DivBy_salary': 0.18275057832870542,
#   'expenses_DivBy_bonus': 0.1293874643874644,
#   'expenses_DivBy_long_term_incentive': 0.0,
#   'expenses_DivBy_total_payments': 0.044174720664182945,
#   'total_payments_DivBy_salary': 0.10562335602157379,
#   'total_payments_DivBy_bonus': 0.08982691529827878,
#   'total_payments_DivBy_long_term_incentive': 0.0,
#   'total_payments_DivBy_deferred_income': 0.0,
#   'total_payments_DivBy_expenses': 0.014176371427655942,
#   'exercised_stock_options_DivBy_restricted_stock': 0.0,
#   'exercised_stock_options_DivBy_total_stock_value': 0.0,
#   'restricted_stock_DivBy_exercised_stock_options': 0.0,
#   'restricted_stock_DivBy_total_stock_value': 1.0,
#   'total_stock_value_DivBy_exercised_stock_options': 0.0,
#   'total_stock_value_DivBy_restricted_stock': 0.015151515151515152,
#   'to_messages_DivBy_from_poi_to_this_person': 0.04960017183537055,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.033170982011694265,
#   'from_poi_to_this_person_DivBy_to_messages': 0.09057459897325519,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.17051913603637742,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.34879860266180984,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.021116706218286353,
#   'from_messages_DivBy_from_this_person_to_poi': 0.09625629424213676,
#   'from_this_person_to_poi_DivBy_from_messages': 0.08887865530739121},
#  'BELDEN TIMOTHY N': {'poi': True,
#   'salary': 0.1489772223637858,
#   'bonus': 0.6532155107187894,
#   'long_term_incentive': 0.0,
#   'deferred_income': 0.2514782736116471,
#   'expenses': 0.07343434299163316,
#   'total_payments': 0.5241591706435814,
#   'exercised_stock_options': 0.027256935028353087,
#   'restricted_stock': 0.007710223969246076,
#   'total_stock_value': 0.02261664092653243,
#   'to_messages': 0.6643221971029055,
#   'from_poi_to_this_person': 0.4318181818181818,
#   'from_messages': 0.05908863294942413,
#   'from_this_person_to_poi': 0.17733990147783252,
#   'shared_receipt_with_poi': 1.0,
#   'salary_DivBy_bonus': 0.0,
#   'salary_DivBy_long_term_incentive': 0.0,
#   'salary_DivBy_expenses': 0.0271201828633213,
#   'salary_DivBy_total_payments': 0.006941319488748245,
#   'bonus_DivBy_salary': 1.0,
#   'bonus_DivBy_long_term_incentive': 0.0,
#   'bonus_DivBy_expenses': 0.3611021771011088,
#   'bonus_DivBy_total_payments': 0.17181203730096656,
#   'long_term_incentive_DivBy_salary': 0.0,
#   'long_term_incentive_DivBy_bonus': 0.0,
#   'long_term_incentive_DivBy_expenses': 0.0,
#   'long_term_incentive_DivBy_total_payments': 0.0,
#   'deferred_income_DivBy_total_payments': 0.960872039257277,
#   'expenses_DivBy_salary': 0.09084969825248036,
#   'expenses_DivBy_bonus': 0.00524928931895295,
#   'expenses_DivBy_long_term_incentive': 0.0,
#   'expenses_DivBy_total_payments': 0.0030224809606433523,
#   'total_payments_DivBy_salary': 0.8308362731850664,
#   'total_payments_DivBy_bonus': 0.06447090191871291,
#   'total_payments_DivBy_long_term_incentive': 0.0,
#   'total_payments_DivBy_deferred_income': 0.9956704615882516,
#   'total_payments_DivBy_expenses': 0.1798044242241408,
#   'exercised_stock_options_DivBy_restricted_stock': 0.09175280011749712,
#   'exercised_stock_options_DivBy_total_stock_value': 0.8448477181993574,
#   'restricted_stock_DivBy_exercised_stock_options': 0.014064307180293488,
#   'restricted_stock_DivBy_total_stock_value': 0.12866185821687057,
#   'total_stock_value_DivBy_exercised_stock_options': 0.015485109320582488,
#   'total_stock_value_DivBy_restricted_stock': 0.10680313790379857,
#   'to_messages_DivBy_from_poi_to_this_person': 0.032689732188703774,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.008375339541746858,
#   'from_poi_to_this_person_DivBy_to_messages': 0.1312780069067062,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.12905270784278208,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.6851157239882387,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.029296631054977255,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03268996696226743,
#   'from_this_person_to_poi_DivBy_from_messages': 0.2231404958677686},
#  'BELFER ROBERT': {'poi': False,
#   'salary': 0.0,
#   'bonus': 0.0,
#   'long_term_incentive': 0.0,
#   'deferred_income': 0.0,
#   'expenses': 0.0,
#   'total_payments': 0.0,
#   'exercised_stock_options': 0.0,
#   'restricted_stock': 0.0,
#   'total_stock_value': 0.0,
#   'to_messages': 0.10575232353679981,
#   'from_poi_to_this_person': 0.07196969696969698,
#   'from_messages': 0.003505257886830245,
#   'from_this_person_to_poi': 0.0180623973727422,
#   'shared_receipt_with_poi': 0.1395180286283747,
#   'salary_DivBy_bonus': 0.0,
#   'salary_DivBy_long_term_incentive': 0.0,
#   'salary_DivBy_expenses': 0.0,
#   'salary_DivBy_total_payments': 0.0,
#   'bonus_DivBy_salary': 0.0,
#   'bonus_DivBy_long_term_incentive': 0.0,
#   'bonus_DivBy_expenses': 0.0,
#   'bonus_DivBy_total_payments': 0.0,
#   'long_term_incentive_DivBy_salary': 0.0,
#   'long_term_incentive_DivBy_bonus': 0.0,
#   'long_term_incentive_DivBy_expenses': 0.0,
#   'long_term_incentive_DivBy_total_payments': 0.0,
#   'deferred_income_DivBy_total_payments': 0.0,
#   'expenses_DivBy_salary': 0.0,
#   'expenses_DivBy_bonus': 0.0,
#   'expenses_DivBy_long_term_incentive': 0.0,
#   'expenses_DivBy_total_payments': 0.0,
#   'total_payments_DivBy_salary': 0.0,
#   'total_payments_DivBy_bonus': 0.0,
#   'total_payments_DivBy_long_term_incentive': 0.0,
#   'total_payments_DivBy_deferred_income': 0.0,
#   'total_payments_DivBy_expenses': 0.0,
#   'exercised_stock_options_DivBy_restricted_stock': 0.0,
#   'exercised_stock_options_DivBy_total_stock_value': 0.0,
#   'restricted_stock_DivBy_exercised_stock_options': 0.0,
#   'restricted_stock_DivBy_total_stock_value': 0.0,
#   'total_stock_value_DivBy_exercised_stock_options': 0.0,
#   'total_stock_value_DivBy_restricted_stock': 0.0,
#   'to_messages_DivBy_from_poi_to_this_person': 0.03049062551755253,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.008891686139548584,
#   'from_poi_to_this_person_DivBy_to_messages': 0.13427506985408258,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.14275517487508924,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.6719541332574738,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.021224872817015364,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03442879499217527,
#   'from_this_person_to_poi_DivBy_from_messages': 0.12121212121212122},
#  'BERBERIAN DAVID': {'poi': False,
#   'salary': 0.151538256375071,
#   'bonus': 0.0,
#   'long_term_incentive': 0.0,
#   'deferred_income': 0.0,
#   'expenses': 0.04949093411289297,
#   'total_payments': 0.014590078626706991,
#   'exercised_stock_options': 0.046809522563947,
#   'restricted_stock': 0.056063960423984864,
#   'total_stock_value': 0.050776054560532365,
#   'to_messages': 0.10575232353679981,
#   'from_poi_to_this_person': 0.07196969696969698,
#   'from_messages': 0.003505257886830245,
#   'from_this_person_to_poi': 0.0180623973727422,
#   'shared_receipt_with_poi': 0.1395180286283747,
#   'salary_DivBy_bonus': 0.0,
#   'salary_DivBy_long_term_incentive': 0.0,
#   'salary_DivBy_expenses': 0.041388944060719704,
#   'salary_DivBy_total_payments': 0.9999999999999999,
#   'bonus_DivBy_salary': 0.0,
#   'bonus_DivBy_long_term_incentive': 0.0,
#   'bonus_DivBy_expenses': 0.0,
#   'bonus_DivBy_total_payments': 0.0,
#   'long_term_incentive_DivBy_salary': 0.0,
#   'long_term_incentive_DivBy_bonus': 0.0,
#   'long_term_incentive_DivBy_expenses': 0.0,
#   'long_term_incentive_DivBy_total_payments': 0.0,
#   'deferred_income_DivBy_total_payments': 0.0,
#   'expenses_DivBy_salary': 0.06060750353625426,
#   'expenses_DivBy_bonus': 0.0,
#   'expenses_DivBy_long_term_incentive': 0.0,
#   'expenses_DivBy_total_payments': 0.06017923685577799,
#   'total_payments_DivBy_salary': 0.0,
#   'total_payments_DivBy_bonus': 0.0,
#   'total_payments_DivBy_long_term_incentive': 0.0,
#   'total_payments_DivBy_deferred_income': 0.0,
#   'total_payments_DivBy_expenses': 0.010272476746460403,
#   'exercised_stock_options_DivBy_restricted_stock': 0.02734907001520352,
#   'exercised_stock_options_DivBy_total_stock_value': 0.6187707191888163,
#   'restricted_stock_DivBy_exercised_stock_options': 0.04875208292190567,
#   'restricted_stock_DivBy_total_stock_value': 0.33855625417373497,
#   'total_stock_value_DivBy_exercised_stock_options': 0.05012289755654448,
#   'total_stock_value_DivBy_restricted_stock': 0.04346662594747085,
#   'to_messages_DivBy_from_poi_to_this_person': 0.03049062551755253,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.008891686139548584,
#   'from_poi_to_this_person_DivBy_to_messages': 0.13427506985408258,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.14275517487508924,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.6719541332574738,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.021224872817015364,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03442879499217527,
#   'from_this_person_to_poi_DivBy_from_messages': 0.12121212121212122},
#  'BERGSIEKER RICHARD P': {'poi': False,
#   'salary': 0.12312198275391963,
#   'bonus': 0.02269861286254729,
#   'long_term_incentive': 0.05126963068521591,
#   'deferred_income': 0.8455259106393603,
#   'expenses': 0.256724359339595,
#   'total_payments': 0.05231389029948499,
#   'exercised_stock_options': 0.0,
#   'restricted_stock': 0.04179730106829232,
#   'total_stock_value': 0.013423904559874656,
#   'to_messages': 0.027296324206648244,
#   'from_poi_to_this_person': 0.007575757575757576,
#   'from_messages': 0.0058838257386079115,
#   'from_this_person_to_poi': 0.0,
#   'shared_receipt_with_poi': 0.04185540858851241,
#   'salary_DivBy_bonus': 0.2281224505142183,
#   'salary_DivBy_long_term_incentive': 0.2535599739847012,
#   'salary_DivBy_expenses': 0.004910680027019004,
#   'salary_DivBy_total_payments': 0.2961742465974583,
#   'bonus_DivBy_salary': 0.04185653905431532,
#   'bonus_DivBy_long_term_incentive': 0.053025368653889696,
#   'bonus_DivBy_expenses': 0.002093421294942207,
#   'bonus_DivBy_total_payments': 0.0643706279697615,
#   'long_term_incentive_DivBy_salary': 0.05838678727032187,
#   'long_term_incentive_DivBy_bonus': 0.06110404982343141,
#   'long_term_incentive_DivBy_expenses': 0.004891720212667597,
#   'long_term_incentive_DivBy_total_payments': 0.04633792861521523,
#   'deferred_income_DivBy_total_payments': 0.9274590874816178,
#   'expenses_DivBy_salary': 0.3608063124607118,
#   'expenses_DivBy_bonus': 0.5870726495726495,
#   'expenses_DivBy_long_term_incentive': 0.18417795078774366,
#   'expenses_DivBy_total_payments': 0.11111248787355237,
#   'total_payments_DivBy_salary': 0.07542821402310353,
#   'total_payments_DivBy_bonus': 0.17204890254840444,
#   'total_payments_DivBy_long_term_incentive': 0.10887217006584049,
#   'total_payments_DivBy_deferred_income': 0.9977412025659186,
#   'total_payments_DivBy_expenses': 0.0052886177742375706,
#   'exercised_stock_options_DivBy_restricted_stock': 0.0,
#   'exercised_stock_options_DivBy_total_stock_value': 0.0,
#   'restricted_stock_DivBy_exercised_stock_options': 0.0,
#   'restricted_stock_DivBy_total_stock_value': 1.0,
#   'total_stock_value_DivBy_exercised_stock_options': 0.0,
#   'total_stock_value_DivBy_restricted_stock': 0.015151515151515152,
#   'to_messages_DivBy_from_poi_to_this_person': 0.09786240098684773,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.012051984225291756,
#   'from_poi_to_this_person_DivBy_to_messages': 0.04805288595078051,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.0536480686695279,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.6010232054190784,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.07657579440875152,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03442879499217527,
#   'from_this_person_to_poi_DivBy_from_messages': 0.0},
#  'BHATNAGAR SANJAY': {'poi': False,
#   'salary': 0.0,
#   'bonus': 0.0,
#   'long_term_incentive': 0.0,
#   'deferred_income': 0.0,
#   'expenses': 0.601604992921727,
#   'total_payments': 0.0058340214519052224,
#   'exercised_stock_options': 0.44970753260187013,
#   'restricted_stock': 0.1739683661759821,
#   'total_stock_value': 0.3147274577735348,
#   'to_messages': 0.03901867202545424,
#   'from_poi_to_this_person': 0.0,
#   'from_messages': 0.0021281922884326485,
#   'from_this_person_to_poi': 0.0016420361247947454,
#   'shared_receipt_with_poi': 0.0835296249320529,
#   'salary_DivBy_bonus': 0.0,
#   'salary_DivBy_long_term_incentive': 0.0,
#   'salary_DivBy_expenses': 0.0,
#   'salary_DivBy_total_payments': 0.0,
#   'bonus_DivBy_salary': 0.0,
#   'bonus_DivBy_long_term_incentive': 0.0,
#   'bonus_DivBy_expenses': 0.0,
#   'bonus_DivBy_total_payments': 0.0,
#   'long_term_incentive_DivBy_salary': 0.0,
#   'long_term_incentive_DivBy_bonus': 0.0,
#   'long_term_incentive_DivBy_expenses': 0.0,
#   'long_term_incentive_DivBy_total_payments': 0.0,
#   'deferred_income_DivBy_total_payments': 0.0,
#   'expenses_DivBy_salary': 0.0,
#   'expenses_DivBy_bonus': 0.0,
#   'expenses_DivBy_long_term_incentive': 0.0,
#   'expenses_DivBy_total_payments': 1.1683003160146805,
#   'total_payments_DivBy_salary': 0.0,
#   'total_payments_DivBy_bonus': 0.0,
#   'total_payments_DivBy_long_term_incentive': 0.0,
#   'total_payments_DivBy_deferred_income': 0.0,
#   'total_payments_DivBy_expenses': -9.574876436992846e-05,
#   'exercised_stock_options_DivBy_restricted_stock': 0.08998827937372171,
#   'exercised_stock_options_DivBy_total_stock_value': 1.0,
#   'restricted_stock_DivBy_exercised_stock_options': 0.014363583143549364,
#   'restricted_stock_DivBy_total_stock_value': 0.15571459904026125,
#   'total_stock_value_DivBy_exercised_stock_options': 0.0,
#   'total_stock_value_DivBy_restricted_stock': 0.08991634144159207,
#   'to_messages_DivBy_from_poi_to_this_person': 0.03049062551755253,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.0024260149671645644,
#   'from_poi_to_this_person_DivBy_to_messages': 0.0,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.0,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.883129550803447,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.021224872817015364,
#   'from_messages_DivBy_from_this_person_to_poi': 0.2629107981220657,
#   'from_this_person_to_poi_DivBy_from_messages': 0.034482758620689655},
#  'BIBI PHILIPPE A': {'poi': False,
#   'salary': 0.148606402882477,
#   'bonus': 0.11727616645649433,
#   'long_term_incentive': 0.13876283680227341,
#   'deferred_income': 0.0,
#   'expenses': 0.16636790364783072,
#   'total_payments': 0.19037983661995514,
#   'exercised_stock_options': 0.042187985985613116,
#   'restricted_stock': 0.022693168540171733,
#   'total_stock_value': 0.03754455450060576,
#   'to_messages': 0.1297831365653521,
#   'from_poi_to_this_person': 0.043560606060606064,
#   'from_messages': 0.003505257886830245,
#   'from_this_person_to_poi': 0.013136288998357963,
#   'shared_receipt_with_poi': 0.2417104547925349,
#   'salary_DivBy_bonus': 0.055468472319816886,
#   'salary_DivBy_long_term_incentive': 0.130934034711237,
#   'salary_DivBy_expenses': 0.01064686003551775,
#   'salary_DivBy_total_payments': 0.07842037694397952,
#   'bonus_DivBy_salary': 0.1802257769391295,
#   'bonus_DivBy_long_term_incentive': 0.1068808399097967,
#   'bonus_DivBy_expenses': 0.028222783466695392,
#   'bonus_DivBy_total_payments': 0.0808500141655082,
#   'long_term_incentive_DivBy_salary': 0.12265825942034546,
#   'long_term_incentive_DivBy_bonus': 0.029551525925011663,
#   'long_term_incentive_DivBy_expenses': 0.0177845552735917,
#   'long_term_incentive_DivBy_total_payments': 0.02645641955113307,
#   'deferred_income_DivBy_total_payments': 0.0,
#   'expenses_DivBy_salary': 0.20562525044777047,
#   'expenses_DivBy_bonus': 0.09313141025641025,
#   'expenses_DivBy_long_term_incentive': 0.05775142511842749,
#   'expenses_DivBy_total_payments': 0.02134818657283862,
#   'total_payments_DivBy_salary': 0.28746523181197,
#   'total_payments_DivBy_bonus': 0.13980821602041987,
#   'total_payments_DivBy_long_term_incentive': 0.1792821953978483,
#   'total_payments_DivBy_deferred_income': 0.0,
#   'total_payments_DivBy_expenses': 0.02956611935706848,
#   'exercised_stock_options_DivBy_restricted_stock': 0.058285418703922634,
#   'exercised_stock_options_DivBy_total_stock_value': 0.7757385956058045,
#   'restricted_stock_DivBy_exercised_stock_options': 0.022753515414754066,
#   'restricted_stock_DivBy_total_stock_value': 0.19282414631061132,
#   'total_stock_value_DivBy_exercised_stock_options': 0.02416179579957073,
#   'total_stock_value_DivBy_restricted_stock': 0.07389033611916479,
#   'to_messages_DivBy_from_poi_to_this_person': 0.07007577403510827,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.0037973974048782326,
#   'from_poi_to_this_person_DivBy_to_messages': 0.06585218922533068,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.05379865269461078,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.8282057729104434,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.07634930581245235,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03755868544600939,
#   'from_this_person_to_poi_DivBy_from_messages': 0.2},
#  'BLACHMAN JEREMY M': {'poi': False,
#   'salary': 0.18323043257976335,
#   'bonus': 0.09836065573770493,
#   'long_term_incentive': 0.3521440963523833,
#   'deferred_income': 0.0,
#   'expenses': 0.36643978208561423,
#   'total_payments': 0.18721428181439112,
#   'exercised_stock_options': 0.021785991357200545,
#   'restricted_stock': 0.009848615953102683,
#   'total_stock_value': 0.01943295630685009,
#   'to_messages': 0.20246169304194928,
#   'from_poi_to_this_person': 0.04734848484848485,
#   'from_messages': 0.0002503755633450175,
#   'from_this_person_to_poi': 0.003284072249589491,
#   'shared_receipt_with_poi': 0.4210907773147309,
#   'salary_DivBy_bonus': 0.08074810661213525,
#   'salary_DivBy_long_term_incentive': 0.05732120018030146,
#   'salary_DivBy_expenses': 0.004366960099174515,
#   'salary_DivBy_total_payments': 0.09920695077370159,
#   'bonus_DivBy_salary': 0.1281442736807864,
#   'bonus_DivBy_long_term_incentive': 0.03810460855615776,
#   'bonus_DivBy_expenses': 0.009157645455859401,
#   'bonus_DivBy_total_payments': 0.06786468387295125,
#   'long_term_incentive_DivBy_salary': 0.2572779633187228,
#   'long_term_incentive_DivBy_bonus': 0.08424204849575903,
#   'long_term_incentive_DivBy_expenses': 0.01835521730831119,
#   'long_term_incentive_DivBy_total_payments': 0.0681723176922425,
#   'deferred_income_DivBy_total_payments': 0.0,
#   'expenses_DivBy_salary': 0.38841616497313813,
#   'expenses_DivBy_bonus': 0.24397352103234457,
#   'expenses_DivBy_long_term_incentive': 0.056025843517266256,
#   'expenses_DivBy_total_payments': 0.04819068686066597,
#   'total_payments_DivBy_salary': 0.23763950334251716,
#   'total_payments_DivBy_bonus': 0.16413537673761686,
#   'total_payments_DivBy_long_term_incentive': 0.07505225175704268,
#   'total_payments_DivBy_deferred_income': 0.0,
#   'total_payments_DivBy_expenses': 0.012956399491675558,
#   'exercised_stock_options_DivBy_restricted_stock': 0.06092976361628999,
#   'exercised_stock_options_DivBy_total_stock_value': 0.7833630049203504,
#   'restricted_stock_DivBy_exercised_stock_options': 0.02172768024826458,
#   'restricted_stock_DivBy_total_stock_value': 0.1857454926014391,
#   'total_stock_value_DivBy_exercised_stock_options': 0.02313743893314761,
#   'total_stock_value_DivBy_restricted_stock': 0.07649086225162315,
#   'to_messages_DivBy_from_poi_to_this_person': 0.10135177581195066,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.0011992225174819564,
#   'from_poi_to_this_person_DivBy_to_messages': 0.046475392220073075,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.033587704213241615,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.9386709528987219,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.12490362910227472,
#   'from_messages_DivBy_from_this_person_to_poi': 0.05633802816901409,
#   'from_this_person_to_poi_DivBy_from_messages': 0.14285714285714285},
#  'BOWEN JR RAYMOND M': {'poi': True,
#   'salary': 0.21302984303627787,
#   'bonus': 0.1614123581336696,
#   'long_term_incentive': 0.41793982224385384,
#   'deferred_income': 1.0013724703212532,
#   'expenses': 0.2862295814834132,
#   'total_payments': 0.2504861442956863,
#   'exercised_stock_options': 0.0,
#   'restricted_stock': 0.014130156130744408,
#   'total_stock_value': 0.005132449596190827,
#   'to_messages': 0.15079963158335427,
#   'from_poi_to_this_person': 0.26515151515151514,
#   'from_messages': 0.0018778167250876315,
#   'from_this_person_to_poi': 0.02463054187192118,
#   'shared_receipt_with_poi': 0.2882768617503171,
#   'salary_DivBy_bonus': 0.05314084010194123,
#   'salary_DivBy_long_term_incentive': 0.05393082607008354,
#   'salary_DivBy_expenses': 0.0074615255955707074,
#   'salary_DivBy_total_payments': 0.07845445231516987,
#   'bonus_DivBy_salary': 0.18702041040686568,
#   'bonus_DivBy_long_term_incentive': 0.05297050637138033,
#   'bonus_DivBy_expenses': 0.021662167319684726,
#   'bonus_DivBy_total_payments': 0.0842311898645456,
#   'long_term_incentive_DivBy_salary': 0.26980613167973533,
#   'long_term_incentive_DivBy_bonus': 0.061166792037594626,
#   'long_term_incentive_DivBy_expenses': 0.028020937847457933,
#   'long_term_incentive_DivBy_total_payments': 0.05957292656340591,
#   'deferred_income_DivBy_total_payments': 1.0001481983763636,
#   'expenses_DivBy_salary': 0.27036324135584955,
#   'expenses_DivBy_bonus': 0.1187108262108262,
#   'expenses_DivBy_long_term_incentive': 0.03706834313549039,
#   'expenses_DivBy_total_payments': 0.028194455324204365,
#   'total_payments_DivBy_salary': 0.2873686844603633,
#   'total_payments_DivBy_bonus': 0.1345238092845629,
#   'total_payments_DivBy_long_term_incentive': 0.08568251236879468,
#   'total_payments_DivBy_deferred_income': -5.12815894899515,
#   'total_payments_DivBy_expenses': 0.022394454078725902,
#   'exercised_stock_options_DivBy_restricted_stock': 0.0,
#   'exercised_stock_options_DivBy_total_stock_value': 0.0,
#   'restricted_stock_DivBy_exercised_stock_options': 0.0,
#   'restricted_stock_DivBy_total_stock_value': 1.0,
#   'total_stock_value_DivBy_exercised_stock_options': 0.0,
#   'total_stock_value_DivBy_restricted_stock': 0.015151515151515152,
#   'to_messages_DivBy_from_poi_to_this_person': 0.009308969985828749,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.003114248863739861,
#   'from_poi_to_this_person_DivBy_to_messages': 0.3466894166685753,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.2746390458254865,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.8547034454036934,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.0114652841515144,
#   'from_messages_DivBy_from_this_person_to_poi': 0.0075117370892018795,
#   'from_this_person_to_poi_DivBy_from_messages': 0.5555555555555556},
#  'BROWN MICHAEL': {'poi': False,
#   'salary': 0.0,
#   'bonus': 0.0,
#   'long_term_incentive': 0.0,
#   'deferred_income': 0.0,
#   'expenses': 0.2133913035855945,
#   'total_payments': -0.002725481034743506,
#   'exercised_stock_options': 0.0,
#   'restricted_stock': 0.0,
#   'total_stock_value': 0.0,
#   'to_messages': 0.11965167880766978,
#   'from_poi_to_this_person': 0.02462121212121212,
#   'from_messages': 0.0036304456685027535,
#   'from_this_person_to_poi': 0.0016420361247947454,
#   'shared_receipt_with_poi': 0.13752491393368363,
#   'salary_DivBy_bonus': 0.0,
#   'salary_DivBy_long_term_incentive': 0.0,
#   'salary_DivBy_expenses': 0.0,
#   'salary_DivBy_total_payments': 0.0,
#   'bonus_DivBy_salary': 0.0,
#   'bonus_DivBy_long_term_incentive': 0.0,
#   'bonus_DivBy_expenses': 0.0,
#   'bonus_DivBy_total_payments': 0.0,
#   'long_term_incentive_DivBy_salary': 0.0,
#   'long_term_incentive_DivBy_bonus': 0.0,
#   'long_term_incentive_DivBy_expenses': 0.0,
#   'long_term_incentive_DivBy_total_payments': 0.0,
#   'deferred_income_DivBy_total_payments': 0.0,
#   'expenses_DivBy_salary': 0.0,
#   'expenses_DivBy_bonus': 0.0,
#   'expenses_DivBy_long_term_incentive': 0.0,
#   'expenses_DivBy_total_payments': 1.1683003160146805,
#   'total_payments_DivBy_salary': 0.0,
#   'total_payments_DivBy_bonus': 0.0,
#   'total_payments_DivBy_long_term_incentive': 0.0,
#   'total_payments_DivBy_deferred_income': 0.0,
#   'total_payments_DivBy_expenses': -9.574876436992846e-05,
#   'exercised_stock_options_DivBy_restricted_stock': 0.0,
#   'exercised_stock_options_DivBy_total_stock_value': 0.0,
#   'restricted_stock_DivBy_exercised_stock_options': 0.0,
#   'restricted_stock_DivBy_total_stock_value': 0.0,
#   'total_stock_value_DivBy_exercised_stock_options': 0.0,
#   'total_stock_value_DivBy_restricted_stock': 0.0,
#   'to_messages_DivBy_from_poi_to_this_person': 0.11778693771006865,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.01783514178937723,
#   'from_poi_to_this_person_DivBy_to_messages': 0.0402515678245182,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.05338370565045992,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.5029794462303391,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.0769765050022039,
#   'from_messages_DivBy_from_this_person_to_poi': 0.3755868544600939,
#   'from_this_person_to_poi_DivBy_from_messages': 0.024390243902439025},
#  'BUCHANAN HAROLD G': {'poi': False,
#   'salary': 0.18270593122785866,
#   'bonus': 0.05422446406052964,
#   'long_term_incentive': 0.10878617035572011,
#   'deferred_income': 0.0,
#   'expenses': 0.0,
#   'total_payments': 0.09442597382266497,
#   'exercised_stock_options': 0.023538080998849846,
#   'restricted_stock': 0.009848615953102683,
#   'total_stock_value': 0.02065777619005207,
#   'to_messages': 0.0863267185799213,
#   'from_poi_to_this_person': 0.0,
#   'from_messages': 0.014146219328993487,
#   'from_this_person_to_poi': 0.0,
#   'shared_receipt_with_poi': 0.003805037144410219,
#   'salary_DivBy_bonus': 0.14608804164144407,
#   'salary_DivBy_long_term_incentive': 0.1931728119297437,
#   'salary_DivBy_expenses': 1.0000000000000002,
#   'salary_DivBy_total_payments': 0.2213494724881843,
#   'bonus_DivBy_salary': 0.07017043569927886,
#   'bonus_DivBy_long_term_incentive': 0.06338265261213281,
#   'bonus_DivBy_expenses': 1.0,
#   'bonus_DivBy_total_payments': 0.07806160219499182,
#   'long_term_incentive_DivBy_salary': 0.08086175693927951,
#   'long_term_incentive_DivBy_bonus': 0.05109879577452733,
#   'long_term_incentive_DivBy_expenses': 1.0,
#   'long_term_incentive_DivBy_total_payments': 0.04593349604138185,
#   'deferred_income_DivBy_total_payments': 0.0,
#   'expenses_DivBy_salary': 0.0,
#   'expenses_DivBy_bonus': 0.0,
#   'expenses_DivBy_long_term_incentive': 0.0,
#   'expenses_DivBy_total_payments': 0.0,
#   'total_payments_DivBy_salary': 0.10775192490528075,
#   'total_payments_DivBy_bonus': 0.1444566621321773,
#   'total_payments_DivBy_long_term_incentive': 0.1097670044879722,
#   'total_payments_DivBy_deferred_income': 0.0,
#   'total_payments_DivBy_expenses': 0.9999999999999998,
#   'exercised_stock_options_DivBy_restricted_stock': 0.0658320625383084,
#   'exercised_stock_options_DivBy_total_stock_value': 0.7962076255885935,
#   'restricted_stock_DivBy_exercised_stock_options': 0.020039237653267622,
#   'restricted_stock_DivBy_total_stock_value': 0.17382029053198736,
#   'total_stock_value_DivBy_exercised_stock_options': 0.02145142950176386,
#   'total_stock_value_DivBy_restricted_stock': 0.08131192640108696,
#   'to_messages_DivBy_from_poi_to_this_person': 0.03049062551755253,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.8668520653869632,
#   'from_poi_to_this_person_DivBy_to_messages': 0.0,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.0,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.0028147081765623576,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.021224872817015364,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03442879499217527,
#   'from_this_person_to_poi_DivBy_from_messages': 0.0},
#  'BUTTS ROBERT H': {'poi': False,
#   'salary': 0.1960901349128525,
#   'bonus': 0.08575031525851198,
#   'long_term_incentive': 0.04884530542111454,
#   'deferred_income': 0.9775391745318867,
#   'expenses': 0.03861274615077817,
#   'total_payments': 0.1153903577073065,
#   'exercised_stock_options': 0.0,
#   'restricted_stock': 0.025379543853648434,
#   'total_stock_value': 0.008503733184866863,
#   'to_messages': 0.10575232353679981,
#   'from_poi_to_this_person': 0.07196969696969698,
#   'from_messages': 0.003505257886830245,
#   'from_this_person_to_poi': 0.0180623973727422,
#   'shared_receipt_with_poi': 0.1395180286283747,
#   'salary_DivBy_bonus': 0.09880756877668241,
#   'salary_DivBy_long_term_incentive': 0.37276949432750245,
#   'salary_DivBy_expenses': 0.06462678282330728,
#   'salary_DivBy_total_payments': 0.18911660355079943,
#   'bonus_DivBy_salary': 0.10534964035170431,
#   'bonus_DivBy_long_term_incentive': 0.1714925478998704,
#   'bonus_DivBy_expenses': 0.09293759139667747,
#   'bonus_DivBy_total_payments': 0.10065541002940949,
#   'long_term_incentive_DivBy_salary': 0.03422858675145802,
#   'long_term_incentive_DivBy_bonus': 0.01730093561944342,
#   'long_term_incentive_DivBy_expenses': 0.03553780127579504,
#   'long_term_incentive_DivBy_total_payments': 0.01874466323178891,
#   'deferred_income_DivBy_total_payments': 0.9947135493152283,
#   'expenses_DivBy_salary': 0.038754997236982454,
#   'expenses_DivBy_bonus': 0.028285849952516613,
#   'expenses_DivBy_long_term_incentive': 0.02923755749386167,
#   'expenses_DivBy_total_payments': 0.007985569949671005,
#   'total_payments_DivBy_salary': 0.12831145095139268,
#   'total_payments_DivBy_bonus': 0.11326921944550343,
#   'total_payments_DivBy_long_term_incentive': 0.23708310249726852,
#   'total_payments_DivBy_deferred_income': 0.9677561120399623,
#   'total_payments_DivBy_expenses': 0.0762642466164234,
#   'exercised_stock_options_DivBy_restricted_stock': 0.0,
#   'exercised_stock_options_DivBy_total_stock_value': 0.0,
#   'restricted_stock_DivBy_exercised_stock_options': 0.0,
#   'restricted_stock_DivBy_total_stock_value': 1.0,
#   'total_stock_value_DivBy_exercised_stock_options': 0.0,
#   'total_stock_value_DivBy_restricted_stock': 0.015151515151515152,
#   'to_messages_DivBy_from_poi_to_this_person': 0.03049062551755253,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.008891686139548584,
#   'from_poi_to_this_person_DivBy_to_messages': 0.13427506985408258,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.14275517487508924,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.6719541332574738,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.021224872817015364,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03442879499217527,
#   'from_this_person_to_poi_DivBy_from_messages': 0.12121212121212122},
#  'BUY RICHARD B': {'poi': False,
#   'salary': 0.26453309960469057,
#   'bonus': 0.1046658259773014,
#   'long_term_incentive': 0.3235384435647094,
#   'deferred_income': 0.7783487745617076,
#   'expenses': 0.0,
#   'total_payments': 0.22015381322376265,
#   'exercised_stock_options': 0.0735613456826753,
#   'restricted_stock': 0.058267920158998746,
#   'total_stock_value': 0.070137742399839,
#   'to_messages': 0.290211839571297,
#   'from_poi_to_this_person': 0.29545454545454547,
#   'from_messages': 0.13032048072108163,
#   'from_this_person_to_poi': 0.11658456486042693,
#   'shared_receipt_with_poi': 0.4223591230295343,
#   'salary_DivBy_bonus': 0.10477124168500172,
#   'salary_DivBy_long_term_incentive': 0.09176785579512348,
#   'salary_DivBy_expenses': 0.0,
#   'salary_DivBy_total_payments': 0.11773359003177336,
#   'bonus_DivBy_salary': 0.09935669841935142,
#   'bonus_DivBy_long_term_incentive': 0.0441192631204837,
#   'bonus_DivBy_expenses': 0.0,
#   'bonus_DivBy_total_payments': 0.06009017246501758,
#   'long_term_incentive_DivBy_salary': 0.1725042733133848,
#   'long_term_incentive_DivBy_bonus': 0.07317630386841385,
#   'long_term_incentive_DivBy_expenses': 0.0,
#   'long_term_incentive_DivBy_total_payments': 0.05272103883985595,
# ...
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.24709302325581395,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.3076949903629528,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.013227378119158759,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03442879499217527,
#   'from_this_person_to_poi_DivBy_from_messages': 0.0},
#  'WALTERS GARETH W': {'poi': False,
#   'salary': 0.0,
#   'bonus': 0.0,
#   'long_term_incentive': 0.0,
#   'deferred_income': 0.0,
#   'expenses': 0.14544426572231256,
#   'total_payments': 0.000958421532498443,
#   'exercised_stock_options': 0.02950542725138902,
#   'restricted_stock': 0.0,
#   'total_stock_value': 0.02097999111302572,
#   'to_messages': 0.10575232353679981,
#   'from_poi_to_this_person': 0.07196969696969698,
#   'from_messages': 0.003505257886830245,
#   'from_this_person_to_poi': 0.0180623973727422,
#   'shared_receipt_with_poi': 0.1395180286283747,
#   'salary_DivBy_bonus': 0.0,
#   'salary_DivBy_long_term_incentive': 0.0,
#   'salary_DivBy_expenses': 0.0,
#   'salary_DivBy_total_payments': 0.0,
#   'bonus_DivBy_salary': 0.0,
#   'bonus_DivBy_long_term_incentive': 0.0,
#   'bonus_DivBy_expenses': 0.0,
#   'bonus_DivBy_total_payments': 0.0,
#   'long_term_incentive_DivBy_salary': 0.0,
#   'long_term_incentive_DivBy_bonus': 0.0,
#   'long_term_incentive_DivBy_expenses': 0.0,
#   'long_term_incentive_DivBy_total_payments': 0.0,
#   'deferred_income_DivBy_total_payments': 0.0,
#   'expenses_DivBy_salary': 0.0,
#   'expenses_DivBy_bonus': 0.0,
#   'expenses_DivBy_long_term_incentive': 0.0,
#   'expenses_DivBy_total_payments': 0.4511539095343952,
#   'total_payments_DivBy_salary': 0.0,
#   'total_payments_DivBy_bonus': 0.0,
#   'total_payments_DivBy_long_term_incentive': 0.0,
#   'total_payments_DivBy_deferred_income': 0.0,
#   'total_payments_DivBy_expenses': 0.0008078598390090395,
#   'exercised_stock_options_DivBy_restricted_stock': 0.0,
#   'exercised_stock_options_DivBy_total_stock_value': 1.0,
#   'restricted_stock_DivBy_exercised_stock_options': 0.0,
#   'restricted_stock_DivBy_total_stock_value': 0.0,
#   'total_stock_value_DivBy_exercised_stock_options': 0.0,
#   'total_stock_value_DivBy_restricted_stock': 0.0,
#   'to_messages_DivBy_from_poi_to_this_person': 0.03049062551755253,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.008891686139548584,
#   'from_poi_to_this_person_DivBy_to_messages': 0.13427506985408258,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.14275517487508924,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.6719541332574738,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.021224872817015364,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03442879499217527,
#   'from_this_person_to_poi_DivBy_from_messages': 0.12121212121212122},
#  'WASAFF GEORGE': {'poi': False,
#   'salary': 0.19458306108507334,
#   'bonus': 0.032156368221942,
#   'long_term_incentive': 0.06038971144064491,
#   'deferred_income': 0.8141907839790842,
#   'expenses': 0.0,
#   'total_payments': 0.09246989712768276,
#   'exercised_stock_options': 0.04808720140621571,
#   'restricted_stock': 0.023378402499157305,
#   'total_stock_value': 0.04187382883000104,
#   'to_messages': 0.02871975215607469,
#   'from_poi_to_this_person': 0.04166666666666667,
#   'from_messages': 0.0022533800701051575,
#   'from_this_person_to_poi': 0.011494252873563218,
#   'shared_receipt_with_poi': 0.060699402065591594,
#   'salary_DivBy_bonus': 0.2436208847542396,
#   'salary_DivBy_long_term_incentive': 0.3214785022236606,
#   'salary_DivBy_expenses': 0.0,
#   'salary_DivBy_total_payments': 0.2390275861344278,
#   'bonus_DivBy_salary': 0.038539736993981326,
#   'bonus_DivBy_long_term_incentive': 0.0627535646529765,
#   'bonus_DivBy_expenses': 0.0,
#   'bonus_DivBy_total_payments': 0.04684109082549618,
#   'long_term_incentive_DivBy_salary': 0.04256463889179889,
#   'long_term_incentive_DivBy_bonus': 0.05161748231692599,
#   'long_term_incentive_DivBy_expenses': 0.0,
#   'long_term_incentive_DivBy_total_payments': 0.028752715841519005,
#   'deferred_income_DivBy_total_payments': 0.9479395938636058,
#   'expenses_DivBy_salary': 0.0,
#   'expenses_DivBy_bonus': 0.0,
#   'expenses_DivBy_long_term_incentive': 0.0,
#   'expenses_DivBy_total_payments': 0.0,
#   'total_payments_DivBy_salary': 0.09852570721625027,
#   'total_payments_DivBy_bonus': 0.2253569915189224,
#   'total_payments_DivBy_long_term_incentive': 0.16703153857028635,
#   'total_payments_DivBy_deferred_income': 0.9967861711289542,
#   'total_payments_DivBy_expenses': 0.0,
#   'exercised_stock_options_DivBy_restricted_stock': 0.06477210754734294,
#   'exercised_stock_options_DivBy_total_stock_value': 0.7935611510267226,
#   'restricted_stock_DivBy_exercised_stock_options': 0.020383121592907817,
#   'restricted_stock_DivBy_total_stock_value': 0.17627733031051504,
#   'total_stock_value_DivBy_exercised_stock_options': 0.02179481788064791,
#   'total_stock_value_DivBy_restricted_stock': 0.08026953565987023,
#   'to_messages_DivBy_from_poi_to_this_person': 0.014581028412887378,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.003499724558715285,
#   'from_poi_to_this_person_DivBy_to_messages': 0.2530585106382979,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.2040059347181009,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.8395514820592824,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.016937915357779915,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03085177733065057,
#   'from_this_person_to_poi_DivBy_from_messages': 0.23333333333333334},
#  'WESTFAHL RICHARD K': {'poi': False,
#   'salary': 0.0,
#   'bonus': 0.0,
#   'long_term_incentive': 0.08633738018638214,
#   'deferred_income': 0.9981696111098435,
#   'expenses': 0.22470777470492587,
#   'total_payments': 0.06616017274393342,
#   'exercised_stock_options': 0.0,
#   'restricted_stock': 0.02315846176289193,
#   'total_stock_value': 0.007838106060430203,
#   'to_messages': 0.10575232353679981,
#   'from_poi_to_this_person': 0.07196969696969698,
#   'from_messages': 0.003505257886830245,
#   'from_this_person_to_poi': 0.0180623973727422,
#   'shared_receipt_with_poi': 0.1395180286283747,
#   'salary_DivBy_bonus': 0.0,
#   'salary_DivBy_long_term_incentive': 0.044132201299981424,
#   'salary_DivBy_expenses': 0.00018789357495234155,
#   'salary_DivBy_total_payments': 0.05581721939392449,
#   'bonus_DivBy_salary': 0.0,
#   'bonus_DivBy_long_term_incentive': 0.0,
#   'bonus_DivBy_expenses': 0.0,
#   'bonus_DivBy_total_payments': 0.0,
#   'long_term_incentive_DivBy_salary': 0.31328846138402894,
#   'long_term_incentive_DivBy_bonus': 0.0,
#   'long_term_incentive_DivBy_expenses': 0.008622271371068278,
#   'long_term_incentive_DivBy_total_payments': 0.054398668200210464,
#   'deferred_income_DivBy_total_payments': 0.9988644488580347,
#   'expenses_DivBy_salary': 0.9367997109164681,
#   'expenses_DivBy_bonus': 0.0,
#   'expenses_DivBy_long_term_incentive': 0.11316075617959095,
#   'expenses_DivBy_total_payments': 0.07889334625676434,
#   'total_payments_DivBy_salary': 0.36737497643926237,
#   'total_payments_DivBy_bonus': 0.0,
#   'total_payments_DivBy_long_term_incentive': 0.09353806035200465,
#   'total_payments_DivBy_deferred_income': 0.8652338043507662,
#   'total_payments_DivBy_expenses': 0.0076997003614673485,
#   'exercised_stock_options_DivBy_restricted_stock': 0.0,
#   'exercised_stock_options_DivBy_total_stock_value': 0.0,
#   'restricted_stock_DivBy_exercised_stock_options': 0.0,
#   'restricted_stock_DivBy_total_stock_value': 1.0,
#   'total_stock_value_DivBy_exercised_stock_options': 0.0,
#   'total_stock_value_DivBy_restricted_stock': 0.015151515151515152,
#   'to_messages_DivBy_from_poi_to_this_person': 0.03049062551755253,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.008891686139548584,
#   'from_poi_to_this_person_DivBy_to_messages': 0.13427506985408258,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.14275517487508924,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.6719541332574738,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.021224872817015364,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03442879499217527,
#   'from_this_person_to_poi_DivBy_from_messages': 0.12121212121212122},
#  'WHALLEY LAWRENCE G': {'poi': False,
#   'salary': 0.44282191642284124,
#   'bonus': 0.3694829760403531,
#   'long_term_incentive': 0.3413094404149337,
#   'deferred_income': 0.0,
#   'expenses': 0.2508645135276097,
#   'total_payments': 0.4445268844584092,
#   'exercised_stock_options': 0.09512048671105065,
#   'restricted_stock': 0.1869927034983487,
#   'total_stock_value': 0.12378593656479227,
#   'to_messages': 0.49920455496943816,
#   'from_poi_to_this_person': 0.3522727272727273,
#   'from_messages': 0.06810215322984475,
#   'from_this_person_to_poi': 0.03940886699507389,
#   'shared_receipt_with_poi': 0.7099112157999637,
#   'salary_DivBy_bonus': 0.04150898966435986,
#   'salary_DivBy_long_term_incentive': 0.14506767926297337,
#   'salary_DivBy_expenses': 0.018613219487681,
#   'salary_DivBy_total_payments': 0.08364087471514287,
#   'bonus_DivBy_salary': 0.22965811156693855,
#   'bonus_DivBy_long_term_incentive': 0.14801645443513992,
#   'bonus_DivBy_expenses': 0.05943755960872735,
#   'bonus_DivBy_total_payments': 0.11071870976880048,
#   'long_term_incentive_DivBy_salary': 0.11042591560903418,
#   'long_term_incentive_DivBy_bonus': 0.020544881081880385,
#   'long_term_incentive_DivBy_expenses': 0.026430992714333825,
#   'long_term_incentive_DivBy_total_payments': 0.02506445078792503,
#   'deferred_income_DivBy_total_payments': 0.0,
#   'expenses_DivBy_salary': 0.12806335028112345,
#   'expenses_DivBy_bonus': 0.04506956315289648,
#   'expenses_DivBy_long_term_incentive': 0.03927236151761161,
#   'expenses_DivBy_total_payments': 0.013789162810678105,
#   'total_payments_DivBy_salary': 0.27331737728952116,
#   'total_payments_DivBy_bonus': 0.10300095238344055,
#   'total_payments_DivBy_long_term_incentive': 0.18759079625134056,
#   'total_payments_DivBy_deferred_income': 0.0,
#   'total_payments_DivBy_expenses': 0.04537591725013594,
#   'exercised_stock_options_DivBy_restricted_stock': 0.01664582207617496,
#   'exercised_stock_options_DivBy_total_stock_value': 0.49695267554209904,
#   'restricted_stock_DivBy_exercised_stock_options': 0.07845261157399927,
#   'restricted_stock_DivBy_total_stock_value': 0.4516545560787531,
#   'total_stock_value_DivBy_exercised_stock_options': 0.07978062567409622,
#   'total_stock_value_DivBy_restricted_stock': 0.03294073886010663,
#   'to_messages_DivBy_from_poi_to_this_person': 0.029803717983744003,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.010024196886242797,
#   'from_poi_to_this_person_DivBy_to_messages': 0.14218273340096788,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.1482780612244898,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.6447425067629055,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.024935257950622396,
#   'from_messages_DivBy_from_this_person_to_poi': 0.2081377151799687,
#   'from_this_person_to_poi_DivBy_from_messages': 0.04316546762589928},
#  'WHITE JR THOMAS E': {'poi': False,
#   'salary': 0.2516406779056036,
#   'bonus': 0.04791929382093317,
#   'long_term_incentive': 0.0,
#   'deferred_income': 0.0,
#   'expenses': 0.3539267979470817,
#   'total_payments': 0.17943751923631643,
#   'exercised_stock_options': 0.03727449757807854,
#   'restricted_stock': 0.9378553610741317,
#   'total_stock_value': 0.30837098242849464,
#   'to_messages': 0.10575232353679981,
#   'from_poi_to_this_person': 0.07196969696969698,
#   'from_messages': 0.003505257886830245,
#   'from_this_person_to_poi': 0.0180623973727422,
#   'shared_receipt_with_poi': 0.1395180286283747,
#   'salary_DivBy_bonus': 0.21335010599255388,
#   'salary_DivBy_long_term_incentive': 0.0,
#   'salary_DivBy_expenses': 0.006675736281702264,
#   'salary_DivBy_total_payments': 0.14377870406803958,
#   'bonus_DivBy_salary': 0.04544059213566229,
#   'bonus_DivBy_long_term_incentive': 0.0,
#   'bonus_DivBy_expenses': 0.003666142728623522,
#   'bonus_DivBy_total_payments': 0.030917193876680897,
#   'long_term_incentive_DivBy_salary': 0.0,
#   'long_term_incentive_DivBy_bonus': 0.0,
#   'long_term_incentive_DivBy_expenses': 0.0,
#   'long_term_incentive_DivBy_total_payments': 0.0,
#   'deferred_income_DivBy_total_payments': 0.0,
#   'expenses_DivBy_salary': 0.29303095101118204,
#   'expenses_DivBy_bonus': 0.44768201962646403,
#   'expenses_DivBy_long_term_incentive': 0.0,
#   'expenses_DivBy_total_payments': 0.048497929536664486,
#   'total_payments_DivBy_salary': 0.1697389306357555,
#   'total_payments_DivBy_bonus': 0.30944831764014163,
#   'total_payments_DivBy_long_term_incentive': 0.0,
#   'total_payments_DivBy_deferred_income': 0.0,
#   'total_payments_DivBy_expenses': 0.012871272651674478,
#   'exercised_stock_options_DivBy_restricted_stock': 0.0,
#   'exercised_stock_options_DivBy_total_stock_value': 0.0,
#   'restricted_stock_DivBy_exercised_stock_options': 1.0,
#   'restricted_stock_DivBy_total_stock_value': 0.9130353339047762,
#   'total_stock_value_DivBy_exercised_stock_options': 1.0,
#   'total_stock_value_DivBy_restricted_stock': 0.016570750549243046,
#   'to_messages_DivBy_from_poi_to_this_person': 0.03049062551755253,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.008891686139548584,
#   'from_poi_to_this_person_DivBy_to_messages': 0.13427506985408258,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.14275517487508924,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.6719541332574738,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.021224872817015364,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03442879499217527,
#   'from_this_person_to_poi_DivBy_from_messages': 0.12121212121212122},
#  'YEAGER F SCOTT': {'poi': True,
#   'salary': 0.09385401412088516,
#   'bonus': 0.0,
#   'long_term_incentive': 0.0,
#   'deferred_income': 0.0,
#   'expenses': 0.23381091588031364,
#   'total_payments': 0.027329025686914667,
#   'exercised_stock_options': 0.24150687573792623,
#   'restricted_stock': 0.23999244170296508,
#   'total_stock_value': 0.24200242565283647,
#   'to_messages': 0.10575232353679981,
#   'from_poi_to_this_person': 0.07196969696969698,
#   'from_messages': 0.003505257886830245,
#   'from_this_person_to_poi': 0.0180623973727422,
#   'shared_receipt_with_poi': 0.1395180286283747,
#   'salary_DivBy_bonus': 0.0,
#   'salary_DivBy_long_term_incentive': 0.0,
#   'salary_DivBy_expenses': 0.004329839443534137,
#   'salary_DivBy_total_payments': 0.444718783584685,
#   'bonus_DivBy_salary': 0.0,
#   'bonus_DivBy_long_term_incentive': 0.0,
#   'bonus_DivBy_expenses': 0.0,
#   'bonus_DivBy_total_payments': 0.0,
#   'long_term_incentive_DivBy_salary': 0.0,
#   'long_term_incentive_DivBy_bonus': 0.0,
#   'long_term_incentive_DivBy_expenses': 0.0,
#   'long_term_incentive_DivBy_total_payments': 0.0,
#   'deferred_income_DivBy_total_payments': 0.0,
#   'expenses_DivBy_salary': 0.3904548387174152,
#   'expenses_DivBy_bonus': 0.0,
#   'expenses_DivBy_long_term_incentive': 0.0,
#   'expenses_DivBy_total_payments': 0.1743618072550676,
#   'total_payments_DivBy_salary': 0.04110311572879674,
#   'total_payments_DivBy_bonus': 0.0,
#   'total_payments_DivBy_long_term_incentive': 0.0,
#   'total_payments_DivBy_deferred_income': 0.0,
#   'total_payments_DivBy_expenses': 0.003137147834738428,
#   'exercised_stock_options_DivBy_restricted_stock': 0.034351305852687086,
#   'exercised_stock_options_DivBy_total_stock_value': 0.6709072614221834,
#   'restricted_stock_DivBy_exercised_stock_options': 0.038932716990402905,
#   'restricted_stock_DivBy_total_stock_value': 0.29015164827730805,
#   'total_stock_value_DivBy_exercised_stock_options': 0.04031768201662744,
#   'total_stock_value_DivBy_restricted_stock': 0.0503528294816045,
#   'to_messages_DivBy_from_poi_to_this_person': 0.03049062551755253,
#   'to_messages_DivBy_shared_receipt_with_poi': 0.008891686139548584,
#   'from_poi_to_this_person_DivBy_to_messages': 0.13427506985408258,
#   'from_poi_to_this_person_DivBy_shared_receipt_with_poi': 0.14275517487508924,
#   'shared_receipt_with_poi_DivBy_to_messages': 0.6719541332574738,
#   'shared_receipt_with_poi_DivBy_from_poi_to_this_person': 0.021224872817015364,
#   'from_messages_DivBy_from_this_person_to_poi': 0.03442879499217527,
#   'from_this_person_to_poi_DivBy_from_messages': 0.12121212121212122}}

# %%
df = pd.DataFrame(data=unpickled_data_dict).T
df['poi'].count()
df['poi'].sum()
set(df['poi'].values)
# Out:
# 123
# 18
# {False, True}

# %%
df.loc['LOCKHART EUGENE E']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\py3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LOCKHART EUGENE E'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-1196de31e23b> in <module>
# ----> 1 df.loc['LOCKHART EUGENE E']
#
# ~\anaconda3\envs\py3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\envs\py3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\envs\py3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\anaconda3\envs\py3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3736                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3737         else:
# -> 3738             loc = index.get_loc(key)
#    3739
#    3740             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\envs\py3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'LOCKHART EUGENE E'
